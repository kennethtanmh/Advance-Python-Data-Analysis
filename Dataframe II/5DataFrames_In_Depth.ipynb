# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# #### Introducing A New Dataset

# %%
# NEW DATA!
# - English Premier League soccer players
# - 400+ players x 17 attributes

# %%
data_url = 'https://andybek.com/pandas-soccer' # as always, this will be attached too!

# %%
players = pd.read_csv(data_url)

# %%
players.info(verbose=False, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 17 entries, name to new_signing
# dtypes: float64(2), int64(10), object(5)
# memory usage: 190.7 KB

# %%
players.dtypes.value_counts()
# Out:
# int64      10
# object      5
# float64     2
# Name: count, dtype: int64

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %% [markdown]
# #### Quick Review: Indexing With Boolean Masks

# %%
# boolean indexing:
#   step 1: generate sequence of booleans
#   step 2: use boolean sequence in [] or .loc[]

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
# Q: what are the players that have a market value exceeding 40M?

# %%
players.market_value > 40
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
players[players.market_value > 40]
# Out:
#                   name               club  age position  position_cat  \
# 0       Alexis Sanchez            Arsenal   28       LW             1
# 1           Mesut Ozil            Arsenal   28       AM             1
# 96         Eden Hazard            Chelsea   26       LW             1
# 97         Diego Costa            Chelsea   28       CF             1
# 108     N%27Golo Kante            Chelsea   26       DM             2
# 218  Philippe Coutinho          Liverpool   25       AM             1
# 244    Kevin De Bruyne    Manchester+City   26       AM             1
# 245      Sergio Aguero    Manchester+City   29       CF             1
# 246    Raheem Sterling    Manchester+City   22       LW             1
# 264      Romelu Lukaku  Manchester+United   24       CF             1
# 267         Paul Pogba  Manchester+United   24       CM             2
# 380          Dele Alli          Tottenham   21       CM             2
# 381         Harry Kane          Tottenham   23       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            65.0        4329       12.0  17.10%         264       3
# 1            50.0        4395        9.5   5.60%         167       2
# 96           75.0        4220       10.5   2.30%         224       2
# 97           50.0        4454       10.0   3.00%         196       2
# 108          50.0        4042        5.0  13.80%          83       2
# 218          45.0        2958        9.0  30.80%         171       3
# 244          65.0        2252       10.0  17.50%         199       2
# 245          65.0        4046       11.5   9.70%         175       3
# 246          45.0        2074        8.0   3.80%         149       1
# 264          50.0        3727       11.5  45.00%         221       2
# 267          75.0        7435        8.0  19.50%         115       2
# 380          45.0        4626        9.5  38.60%         225       1
# 381          60.0        4161       12.5  35.10%         224       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0         Chile            0        4        1         1            0
# 1       Germany            0        4        1         1            0
# 96      Belgium            0        3        5         1            0
# 97        Spain            0        4        5         1            0
# 108      France            0        3        5         1            1
# 218      Brazil            0        3       10         1            0
# 244     Belgium            0        3       11         1            0
# 245   Argentina            0        4       11         1            0
# 246     England            0        2       11         1            0
# 264     Belgium            0        2       12         1            0
# 267      France            0        2       12         1            1
# 380     England            0        1       17         1            0
# 381     England            0        2       17         1            0

# %%
players[players.market_value > 40].shape
# Out:
# (13, 17)

# %% [markdown]
# #### More Approaches To Boolean Masking

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.position.unique().size
# Out:
# 14

# %%
# defender codes: LB, CB, RB

# %%
players.position.isin(['LB', 'CB', 'RB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 460    False
# 461     True
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
players.loc[players.position.isin(['LB', 'CB', 'RB'])]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 4           912        6.0   0.70%         121       2      France
# 5          1675        6.0  13.70%         119       2       Spain
# 7           555        5.5   4.70%         115       2       Spain
# 8          1877        5.5   4.00%          90       2     Germany
# 17          552        5.0   0.10%          45       3      Brazil
# ..          ...        ...     ...         ...     ...         ...
# 455         380        5.0   1.30%          60       1     England
# 458         247        4.5   1.10%          45       2       Italy
# 459         698        5.0   2.70%          45       3   Argentina
# 461         199        4.5   0.20%          34       4    Congo DR
# 462         198        4.5   0.30%          29       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 4              0        4        1         1            0
# 5              0        2        1         1            0
# 7              0        4        1         1            0
# 8              0        3        1         1            1
# 17             0        3        1         1            0
# ..           ...      ...      ...       ...          ...
# 455            0        3       20         0            0
# 458            0        4       20         0            0
# 459            0        5       20         0            0
# 461            0        2       20         0            1
# 462            0        2       20         0            0
#
# [154 rows x 17 columns]

# %%
# players.market_value.between(40,50, inclusive=False)

# %%
players[players.market_value.between(40,50, inclusive=True)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 players[players.market_value.between(40,50, inclusive=True)]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:5497, in Series.between(self, left, right, inclusive)
#    5495     rmask = self < right
#    5496 else:
# -> 5497     raise ValueError(
#    5498         "Inclusive has to be either string of 'both',"
#    5499         "'left', 'right', or 'neither'."
#    5500     )
#    5502 return lmask & rmask
#
# ValueError: Inclusive has to be either string of 'both','left', 'right', or 'neither'.

# %%
players.age <= 25
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462     True
# 463     True
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
players.loc[players.age <= 25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 5          1675        6.0  13.70%         119       2        Spain
# 8          1877        5.5   4.00%          90       2      Germany
# 9          1812        5.5   1.00%          89       4      Nigeria
# 10         1815        5.5   2.00%          85       2  Switzerland
# 11         1815        5.5   2.00%          85       2  Switzerland
# ..          ...        ...     ...         ...     ...          ...
# 456         286        4.5   0.30%          55       2        Spain
# 460         288        4.5   0.40%          38       2  Switzerland
# 461         199        4.5   0.20%          34       4     Congo DR
# 462         198        4.5   0.30%          29       1      England
# 463         412        4.5   5.90%          16       1      England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 8              0        3        1         1            1
# 9              0        1        1         1            0
# 10             0        2        1         1            0
# 11             0        2        1         1            0
# ..           ...      ...      ...       ...          ...
# 456            0        3       20         0            0
# 460            0        1       20         0            1
# 461            0        2       20         0            1
# 462            0        2       20         0            0
# 463            0        1       20         0            1
#
# [172 rows x 17 columns]

# %%
players.loc[players.age.le(25)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 5          1675        6.0  13.70%         119       2        Spain
# 8          1877        5.5   4.00%          90       2      Germany
# 9          1812        5.5   1.00%          89       4      Nigeria
# 10         1815        5.5   2.00%          85       2  Switzerland
# 11         1815        5.5   2.00%          85       2  Switzerland
# ..          ...        ...     ...         ...     ...          ...
# 456         286        4.5   0.30%          55       2        Spain
# 460         288        4.5   0.40%          38       2  Switzerland
# 461         199        4.5   0.20%          34       4     Congo DR
# 462         198        4.5   0.30%          29       1      England
# 463         412        4.5   5.90%          16       1      England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 8              0        3        1         1            1
# 9              0        1        1         1            0
# 10             0        2        1         1            0
# 11             0        2        1         1            0
# ..           ...      ...      ...       ...          ...
# 456            0        3       20         0            0
# 460            0        1       20         0            1
# 461            0        2       20         0            1
# 462            0        2       20         0            0
# 463            0        1       20         0            1
#
# [172 rows x 17 columns]

# %%
players.age.le(25).equals(players.age <= 25)
# Out:
# True

# %% [markdown]
# #### Binary Operators With Booleans

# %%
# Binary OR -> |

# %%
True | False
# Out:
# True

# %%
False | False
# Out:
# False

# %%
False | True
# Out:
# True

# %%
True | True
# Out:
# True

# %%
# Binary AND -> &

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True & True
# Out:
# True

# %%
# a single false is enough!

# %%
True & True & False & True & True
# Out:
# False

# %%
f = pd.Series(False)

# %%
f
# Out:
# 0    False
# dtype: bool

# %%
t = pd.Series(True)

# %%
t
# Out:
# 0    True
# dtype: bool

# %%
t & f
# Out:
# 0    False
# dtype: bool

# %%
t | f
# Out:
# 0    True
# dtype: bool

# %%
t = pd.Series([True if i%2 ==0 else False for i in range(10)])

# %%
t
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
f = pd.Series([False for i in range(10)])

# %%
f
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
t & f
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
t | f
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
f = pd.Series(data=[False, True, True], index=['c','b', 'a'])
t = pd.Series(data=[True, False, False], index=['a', 'b', 'c'])

# %%
f
# Out:
# c    False
# b     True
# a     True
# dtype: bool

# %%
t
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %%
f & t
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %% [markdown]
# #### BONUS - XOR And Complement Binary Ops

# %%
# Binary XOR -> ^

# %%
True ^ False
# Out:
# True

# %%
False ^ False
# Out:
# False

# %%
True ^ True
# Out:
# False

# %%
True ^ (False | False & True) | False
# Out:
# True

# %%
# (Two's) Complement -> ~

# %%
# tilde (~) negates

# %%
~False
# Out:
# -1

# %%
~0
# Out:
# -1

# %%
~True
# Out:
# -2

# %%
~1
# Out:
# -2

# %%
t = pd.Series([True, True, False])

# %%
t
# Out:
# 0     True
# 1     True
# 2    False
# dtype: bool

# %%
~t
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %% [markdown]
# #### Combining Conditions

# %%
# select all the left backs -> LB

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
# all left backs who are 25 or younger

# %%
players[
        (players.position == 'LB') & 
        (players.age <= 25)
        ]
# Out:
#                  name               club  age position  position_cat  \
# 29     Sead Kolasinac            Arsenal   24       LB             3
# 54         Brad Smith        Bournemouth   23       LB             3
# 112            Kenedy            Chelsea   21       LB             3
# 128   Jeffrey Schlupp     Crystal+Palace   24       LB             3
# 212      Ben Chilwell     Leicester+City   20       LB             3
# 236    Alberto Moreno          Liverpool   25       LB             3
# 281         Luke Shaw  Manchester+United   22       LB             3
# 294      Paul Dummett   Newcastle+United   25       LB             3
# 298  Massadio Haidara   Newcastle+United   24       LB             3
# 328      Matt Targett        Southampton   21       LB             3
# 354        Josh Tymon         Stoke+City   18       LB             3
# 369  Stephen Kingsley            Swansea   22       LB             3
# 389        Ben Davies          Tottenham   24       LB             3
# 461    Arthur Masuaku           West+Ham   23       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29          15.00         618        6.0   6.90%           0       2
# 54           2.00         297        4.0   3.30%           4       4
# 112          7.00         566        5.0   0.10%           3       3
# 128          8.00         385        5.0   0.30%          47       4
# 212          2.50         288        4.5   0.80%          19       1
# 236         10.00         397        4.5   0.30%           8       2
# 281         20.00         947        5.0   0.40%          45       1
# 294          3.50         177        4.5   1.00%           0       2
# 298          1.50         114        4.0   0.50%           0       2
# 328          3.00         110        4.5   0.20%          12       1
# 354          1.00         120        4.5   0.10%           9       1
# 369          0.75         168        4.5   0.20%          29       2
# 389         12.00         396        5.5   1.80%          90       2
# 461          7.00         199        4.5   0.20%          34       4
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29       Bosnia            1        2        1         1            0
# 54    Australia            0        2        2         0            0
# 112      Brazil            0        1        5         1            0
# 128       Ghana            0        2        6         0            0
# 212     England            0        1        9         0            0
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0
# 294       Wales            0        3       13         0            0
# 298      France            0        2       13         0            0
# 328     England            0        1       14         0            0
# 354     England            0        1       15         0            0
# 369    Scotland            0        2       16         0            0
# 389       Wales            0        2       17         1            0
# 461    Congo DR            0        2       20         0            1

# %%
# 3 conditions: left backs, 25 or younger, market value 10+

# %%
players[
        (players.position == 'LB') & 
        (players.age <= 25) & 
        (players.market_value >= 10)
        ]
# Out:
#                name               club  age position  position_cat  \
# 29   Sead Kolasinac            Arsenal   24       LB             3
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
# 389      Ben Davies          Tottenham   24       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
# 389          12.0         396        5.5   1.80%          90       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29       Bosnia            1        2        1         1            0
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0
# 389       Wales            0        2       17         1            0

# %%
# 4 conditions: left backs, 25 or younger, market value 10+, and NOT from Arsenal or Tottenham clubs

# %%
players[
        (players.position == 'LB') &
        (players.age <= 25) &
        (players.market_value >= 10) &
        ~(players.club.isin(['Tottenham', 'Arsenal']))
        ]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %% [markdown]
# #### Conditions As Variables

# %%
players[
        (players.position == 'LB') &
        (players.age <= 25) &
        (players.market_value >= 10) &
        ~(players.club.isin(['Tottenham', 'Arsenal']))
        ]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
# new target: Arsenal right backs and Chelsea goalkeepers

# %%
arsenal_player = players.club == 'Arsenal'

# %%
arsenal_player
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: club, Length: 465, dtype: bool

# %%
right_back = players.position == 'RB'

# %%
right_back
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
chelsea_and_GK = (players.club == 'Chelsea') & (players.position == 'GK')

# %%
chelsea_and_GK
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players.loc[arsenal_player & right_back | chelsea_and_GK]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 5     Hector Bellerin  Arsenal   22       RB             3          30.0
# 27     Carl Jenkinson  Arsenal   25       RB             3           5.0
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5          1675        6.0  13.70%         119       2       Spain
# 27          561        4.5   0.40%           2       1     England
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 27             0        3        1         1            0
# 102            0        3        5         1            0
# 109            0        6        5         1            0

# %% [markdown]
# #### Skill Challenge

# %% [markdown]
# ######Find the players in our dataset that meet these criteria
#
# 1.   they're English (*nationality*), and
# 2.   their market value is more than twice the average market value in the league (*market_value*), and
# 3. they either have more than 4,000 views (*page_views*) or are a new signing (*new_signing*) but not both

# %%
english_players = players.nationality == 'England'

# %%
english_players.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: nationality, dtype: bool

# %%
twice_mkt_value = players.market_value.mean() * 2
expensive_players = players.market_value > twice_mkt_value

# %%
expensive_players.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: market_value, dtype: bool

# %%
page_view = players.page_views > 4000
new_sign = players.new_signing = 1
either_player = page_view ^ new_sign

# %%
players[english_players & expensive_players & either_player]
# Out:
#                  name             club age position  position_cat  \
# 137      Ross Barkley          Everton  23       AM             1
# 222      Adam Lallana        Liverpool  29       AM             1
# 229  Jordan Henderson        Liverpool  27       CM             2
# 246   Raheem Sterling  Manchester+City  22       LW             1
# 247       Kyle Walker  Manchester+City  27       RB             3
# 256       John Stones  Manchester+City  23       CB             3
# 388         Eric Dier        Tottenham  23       DM             2
# 390        Danny Rose        Tottenham  27       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 137          25.0        1413        7.5   0.70%         144       1
# 222          25.0        1808        7.5   6.40%         139       1
# 229          28.0        1236        5.5   1.80%          73       1
# 246          45.0        2074        8.0   3.80%         149       1
# 247          30.0        1008        6.5  18.50%         142       1
# 256          35.0        1078        5.5   2.30%          59       1
# 388          25.0        1239        5.0   3.50%          93       1
# 390          28.0         848        6.5   0.60%          84       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing  \
# 137     England            0        2        7         0            1
# 222     England            0        4       10         1            1
# 229     England            0        3       10         1            1
# 246     England            0        2       11         1            1
# 247     England            0        3       11         1            1
# 256     England            0        2       11         1            1
# 388     England            0        2       17         1            1
# 390     England            0        3       17         1            1
#
#         popularity   MVtoFPL
# 137        popular  3.333333
# 222        popular  3.333333
# 229        popular  5.090909
# 246  super-popular  5.625000
# 247        popular  4.615385
# 256        popular  6.363636
# 388        popular  5.000000
# 390        popular  4.307692

# %% [markdown]
# #### Solution

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
# first condition

# %%
english = players.nationality == 'England'

# %%
english.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: nationality, dtype: bool

# %%
# second condtion

# %%
players.market_value.mean()
# Out:
# 11.125649350649349

# %%
above_average = players.market_value > players.market_value.mean() * 2

# %%
above_average.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: market_value, dtype: bool

# %%
# third condition

# %%
popular_xor_new = (players.page_views > 4000) ^ (players.new_signing == 1)

# %%
popular_xor_new.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
print(english.shape)
# Out:
# (465,)

# %%
print(above_average.shape)
print(popular_xor_new.shape)
print(players.shape)
# Out:
# (465,)
# (465,)
# (465, 17)

# %%
players.loc[english & above_average & popular_xor_new]
# Out:
#                  name             club age position  position_cat  \
# 137      Ross Barkley          Everton  23       AM             1
# 222      Adam Lallana        Liverpool  29       AM             1
# 229  Jordan Henderson        Liverpool  27       CM             2
# 246   Raheem Sterling  Manchester+City  22       LW             1
# 247       Kyle Walker  Manchester+City  27       RB             3
# 256       John Stones  Manchester+City  23       CB             3
# 380         Dele Alli        Tottenham  21       CM             2
# 381        Harry Kane        Tottenham  23       CF             1
# 388         Eric Dier        Tottenham  23       DM             2
# 390        Danny Rose        Tottenham  27       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 137          25.0        1413        7.5   0.70%         144       1
# 222          25.0        1808        7.5   6.40%         139       1
# 229          28.0        1236        5.5   1.80%          73       1
# 246          45.0        2074        8.0   3.80%         149       1
# 247          30.0        1008        6.5  18.50%         142       1
# 256          35.0        1078        5.5   2.30%          59       1
# 380          45.0        4626        9.5  38.60%         225       1
# 381          60.0        4161       12.5  35.10%         224       1
# 388          25.0        1239        5.0   3.50%          93       1
# 390          28.0         848        6.5   0.60%          84       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing  \
# 137     England            0        2        7         0            0
# 222     England            0        4       10         1            0
# 229     England            0        3       10         1            0
# 246     England            0        2       11         1            0
# 247     England            0        3       11         1            0
# 256     England            0        2       11         1            1
# 380     England            0        1       17         1            0
# 381     England            0        2       17         1            0
# 388     England            0        2       17         1            0
# 390     England            0        3       17         1            0
#
#         popularity   MVtoFPL
# 137        popular  3.333333
# 222        popular  3.333333
# 229        popular  5.090909
# 246  super-popular  5.625000
# 247        popular  4.615385
# 256        popular  6.363636
# 380  super-popular  4.736842
# 381  super-popular  4.800000
# 388        popular  5.000000
# 390        popular  4.307692

# %% [markdown]
# #### 2d Indexing

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
# chelsea players and 23 years old or younger

# %%
chelsea_23under = (players.club == 'Chelsea') & (players.age.le(23))

# %%
chelsea_23under.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
players.loc[chelsea_23under, ['position', 'market_value']]
# Out:
#     position  market_value
# 110       CF          25.0
# 111       CB          15.0
# 112       LB           7.0
# 115       DM          16.0

# %%
# ...select all column that begin with 'p'

# %%
# startwith

# %%
p_cols = players.columns.str.startswith('p')

# %%
players.loc[chelsea_23under, p_cols]
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %%
print(chelsea_23under.shape)
# Out:
# (465,)

# %%
print(players.shape)
# Out:
# (465, 17)

# %%
print(p_cols.shape)
# Out:
# (17,)

# %%
# [] chaining

# %%
players[chelsea_23under]['position']
# Out:
# 110    CF
# 111    CB
# 112    LB
# 115    DM
# Name: position, dtype: object

# %%
players.loc[chelsea_23under, 'position']
# Out:
# 110    CF
# 111    CB
# 112    LB
# 115    DM
# Name: position, dtype: object

# %% [markdown]
# #### Fancy Indexing With lookup()

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.loc[[0, 132], ('name', 'market_value')] # fancy
# Out:
#                name  market_value
# 0    Alexis Sanchez          65.0
# 132  Connor Wickham           6.0

# %%
players.lookup([0, 132], ['name', 'market_value'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/2318317589.py in ?()
# ----> 1 players.lookup([0, 132], ['name', 'market_value'])
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lookup'

# %%
players.lookup([0, 132], ['market_value', 'name'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/155885538.py in ?()
# ----> 1 players.lookup([0, 132], ['market_value', 'name'])
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lookup'

# %%
names = ['Petr Cech', 'Mesut Ozil', 'Alexis Sanchez']

# %%
attributes = ['age', 'market_value', 'page_views']

# %%
players.set_index('name').lookup(names, attributes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/4137716727.py in ?()
# ----> 1 players.set_index('name').lookup(names, attributes)
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lookup'

# %% [markdown]
# #### Sorting By Index Or Column

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.sort_values(by='market_value', ascending=False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 96          75.00        4220       10.5   2.30%         224       2
# 267         75.00        7435        8.0  19.50%         115       2
# 0           65.00        4329       12.0  17.10%         264       3
# 244         65.00        2252       10.0  17.50%         199       2
# 245         65.00        4046       11.5   9.70%         175       3
# ..            ...         ...        ...     ...         ...     ...
# 287          0.10         395        4.0   1.00%           6       2
# 113          0.05         467        5.0   0.10%           0       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 96       Belgium            0        3        5         1            0
# 267       France            0        2       12         1            1
# 0          Chile            0        4        1         1            0
# 244      Belgium            0        3       11         1            0
# 245    Argentina            0        4       11         1            0
# ..           ...          ...      ...      ...       ...          ...
# 287     Portugal            0        1       12         1            0
# 113     Portugal            0        6        5         1            1
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0
#
# [465 rows x 17 columns]

# %%
players.index
# Out:
# RangeIndex(start=0, stop=465, step=1)

# %%
players.set_index('name', inplace=True)

# %%
players.head(10)
# Out:
#                       club  age position  position_cat  market_value  \
# name
# Alexis Sanchez     Arsenal   28       LW             1          65.0
# Mesut Ozil         Arsenal   28       AM             1          50.0
# Petr Cech          Arsenal   35       GK             4           7.0
# Theo Walcott       Arsenal   28       RW             1          20.0
# Laurent Koscielny  Arsenal   31       CB             3          22.0
# Hector Bellerin    Arsenal   22       RB             3          30.0
# Olivier Giroud     Arsenal   30       CF             1          22.0
# Nacho Monreal      Arsenal   31       LB             3          13.0
# Shkodran Mustafi   Arsenal   25       CB             3          30.0
# Alex Iwobi         Arsenal   21       LW             1          10.0
#
#                    page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Alexis Sanchez           4329       12.0  17.10%         264       3
# Mesut Ozil               4395        9.5   5.60%         167       2
# Petr Cech                1529        5.5   5.90%         134       2
# Theo Walcott             2393        7.5   1.50%         122       1
# Laurent Koscielny         912        6.0   0.70%         121       2
# Hector Bellerin          1675        6.0  13.70%         119       2
# Olivier Giroud           2230        8.5   2.50%         116       2
# Nacho Monreal             555        5.5   4.70%         115       2
# Shkodran Mustafi         1877        5.5   4.00%          90       2
# Alex Iwobi               1812        5.5   1.00%          89       4
#
#                       nationality  new_foreign  age_cat  club_id  big_club  \
# name
# Alexis Sanchez              Chile            0        4        1         1
# Mesut Ozil                Germany            0        4        1         1
# Petr Cech          Czech Republic            0        6        1         1
# Theo Walcott              England            0        4        1         1
# Laurent Koscielny          France            0        4        1         1
# Hector Bellerin             Spain            0        2        1         1
# Olivier Giroud             France            0        4        1         1
# Nacho Monreal               Spain            0        4        1         1
# Shkodran Mustafi          Germany            0        3        1         1
# Alex Iwobi                Nigeria            0        1        1         1
#
#                    new_signing
# name
# Alexis Sanchez               0
# Mesut Ozil                   0
# Petr Cech                    0
# Theo Walcott                 0
# Laurent Koscielny            0
# Hector Bellerin              0
# Olivier Giroud               0
# Nacho Monreal                0
# Shkodran Mustafi             1
# Alex Iwobi                   0

# %%
players.index
# Out:
# Index(['Alexis Sanchez', 'Mesut Ozil', 'Petr Cech', 'Theo Walcott',
#        'Laurent Koscielny', 'Hector Bellerin', 'Olivier Giroud',
#        'Nacho Monreal', 'Shkodran Mustafi', 'Alex Iwobi',
#        ...
#        'Aaron Cresswell', 'Pedro Obiang', 'Sofiane Feghouli', 'Angelo Ogbonna',
#        'Pablo Zabaleta', 'Edimilson Fernandes', 'Arthur Masuaku', 'Sam Byram',
#        'Ashley Fletcher', 'Diafra Sakho'],
#       dtype='object', name='name', length=465)

# %%
players.sort_index(inplace=True)

# %%
players.head(10)
# Out:
#                             club  age position  position_cat  market_value  \
# name
# Aaron Cresswell         West+Ham   27       LB             3          12.0
# Aaron Lennon             Everton   30       RW             1           5.0
# Aaron Mooy          Huddersfield   26       CM             2           5.0
# Aaron Ramsey             Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure       Watford   24       CM             2           6.0
# Adam Federici        Bournemouth   32       GK             4           1.0
# Adam Lallana           Liverpool   29       AM             1          25.0
# Adam Smith           Bournemouth   26       RB             3           5.0
# Ademola Lookman          Everton   19       LW             1           5.0
# Adrian                  West+Ham   30       GK             4           8.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Aaron Cresswell            380        5.0   1.30%          60       1
# Aaron Lennon               504        5.5   0.20%          22       1
# Aaron Mooy                 588        5.5   2.50%           0       4
# Aaron Ramsey              1040        7.0   5.10%          56       1
# Abdoulaye Doucoure         124        5.0   0.00%          38       2
# Adam Federici              126        4.0   1.50%           8       4
# Adam Lallana              1808        7.5   6.40%         139       1
# Adam Smith                 200        5.0   0.90%         104       1
# Ademola Lookman           1387        5.5   0.30%          16       1
# Adrian                     266        4.5   0.80%          64       2
#
#                    nationality  new_foreign  age_cat  club_id  big_club  \
# name
# Aaron Cresswell        England            0        3       20         0
# Aaron Lennon           England            0        4        7         0
# Aaron Mooy           Australia            0        3        8         0
# Aaron Ramsey             Wales            0        3        1         1
# Abdoulaye Doucoure      France            0        2       18         0
# Adam Federici        Australia            0        5        2         0
# Adam Lallana           England            0        4       10         1
# Adam Smith             England            0        3        2         0
# Ademola Lookman        England            0        1        7         0
# Adrian                   Spain            0        4       20         0
#
#                     new_signing
# name
# Aaron Cresswell               0
# Aaron Lennon                  0
# Aaron Mooy                    0
# Aaron Ramsey                  0
# Abdoulaye Doucoure            0
# Adam Federici                 0
# Adam Lallana                  0
# Adam Smith                    0
# Ademola Lookman               0
# Adrian                        0

# %%
players.sort_index(axis=1)
# Out:
#                     age  age_cat  big_club            club  club_id  \
# name
# Aaron Cresswell      27        3         0        West+Ham       20
# Aaron Lennon         30        4         0         Everton        7
# Aaron Mooy           26        3         0    Huddersfield        8
# Aaron Ramsey         26        3         1         Arsenal        1
# Abdoulaye Doucoure   24        2         0         Watford       18
# ...                 ...      ...       ...             ...      ...
# Yohan Cabaye         31        4         0  Crystal+Palace        6
# YounÃ¨s Kaboul       31        4         0         Watford       18
# Ã‰tienne Capoue      29        4         0         Watford       18
# Ã€ngel Rangel        34        6         0         Swansea       16
# Åukasz FabiaÅ„ski   32        5         0         Swansea       16
#
#                     fpl_points fpl_sel  fpl_value  market_value nationality  \
# name
# Aaron Cresswell             60   1.30%        5.0          12.0     England
# Aaron Lennon                22   0.20%        5.5           5.0     England
# Aaron Mooy                   0   2.50%        5.5           5.0   Australia
# Aaron Ramsey                56   5.10%        7.0          35.0       Wales
# Abdoulaye Doucoure          38   0.00%        5.0           6.0      France
# ...                        ...     ...        ...           ...         ...
# Yohan Cabaye                91   1.40%        5.5          15.0      France
# YounÃ¨s Kaboul              57   0.10%        4.5           2.5      France
# Ã‰tienne Capoue            131   8.00%        5.5           9.0      France
# Ã€ngel Rangel               26  18.80%        4.0           1.0       Spain
# Åukasz FabiaÅ„ski         116   6.20%        4.5           9.0      Poland
#
#                     new_foreign  new_signing  page_views position  \
# name
# Aaron Cresswell               0            0         380       LB
# Aaron Lennon                  0            0         504       RW
# Aaron Mooy                    0            0         588       CM
# Aaron Ramsey                  0            0        1040       CM
# Abdoulaye Doucoure            0            0         124       CM
# ...                         ...          ...         ...      ...
# Yohan Cabaye                  0            0         456       CM
# YounÃ¨s Kaboul                0            1         263       CB
# Ã‰tienne Capoue               0            0         412       DM
# Ã€ngel Rangel                 0            0         137       RB
# Åukasz FabiaÅ„ski            0            0         285       GK
#
#                     position_cat  region
# name
# Aaron Cresswell                3       1
# Aaron Lennon                   1       1
# Aaron Mooy                     2       4
# Aaron Ramsey                   2       1
# Abdoulaye Doucoure             2       2
# ...                          ...     ...
# Yohan Cabaye                   2       2
# YounÃ¨s Kaboul                 3       2
# Ã‰tienne Capoue                2       2
# Ã€ngel Rangel                  3       2
# Åukasz FabiaÅ„ski             4       2
#
# [465 rows x 16 columns]

# %%
players.reset_index()
# Out:
#                    name            club  age position  position_cat  \
# 0       Aaron Cresswell        West+Ham   27       LB             3
# 1          Aaron Lennon         Everton   30       RW             1
# 2            Aaron Mooy    Huddersfield   26       CM             2
# 3          Aaron Ramsey         Arsenal   26       CM             2
# 4    Abdoulaye Doucoure         Watford   24       CM             2
# ..                  ...             ...  ...      ...           ...
# 460        Yohan Cabaye  Crystal+Palace   31       CM             2
# 461      YounÃ¨s Kaboul         Watford   31       CB             3
# 462     Ã‰tienne Capoue         Watford   29       DM             2
# 463       Ã€ngel Rangel         Swansea   34       RB             3
# 464  Åukasz FabiaÅ„ski         Swansea   32       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            12.0         380        5.0   1.30%          60       1
# 1             5.0         504        5.5   0.20%          22       1
# 2             5.0         588        5.5   2.50%           0       4
# 3            35.0        1040        7.0   5.10%          56       1
# 4             6.0         124        5.0   0.00%          38       2
# ..            ...         ...        ...     ...         ...     ...
# 460          15.0         456        5.5   1.40%          91       2
# 461           2.5         263        4.5   0.10%          57       2
# 462           9.0         412        5.5   8.00%         131       2
# 463           1.0         137        4.0  18.80%          26       2
# 464           9.0         285        4.5   6.20%         116       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0       England            0        3       20         0            0
# 1       England            0        4        7         0            0
# 2     Australia            0        3        8         0            0
# 3         Wales            0        3        1         1            0
# 4        France            0        2       18         0            0
# ..          ...          ...      ...      ...       ...          ...
# 460      France            0        4        6         0            0
# 461      France            0        4       18         0            1
# 462      France            0        4       18         0            0
# 463       Spain            0        6       16         0            0
# 464      Poland            0        5       16         0            0
#
# [465 rows x 17 columns]

# %%
players.reset_index().reset_index().reset_index()
# Out:
#      level_0  index                name            club  age position  \
# 0          0      0     Aaron Cresswell        West+Ham   27       LB
# 1          1      1        Aaron Lennon         Everton   30       RW
# 2          2      2          Aaron Mooy    Huddersfield   26       CM
# 3          3      3        Aaron Ramsey         Arsenal   26       CM
# 4          4      4  Abdoulaye Doucoure         Watford   24       CM
# ..       ...    ...                 ...             ...  ...      ...
# 460      460    460        Yohan Cabaye  Crystal+Palace   31       CM
# 461      461    461      YounÃ¨s Kaboul         Watford   31       CB
# 462      462    462     Ã‰tienne Capoue         Watford   29       DM
# 463      463    463       Ã€ngel Rangel         Swansea   34       RB
# 464      464    464  Åukasz FabiaÅ„ski         Swansea   32       GK
#
#      position_cat  market_value  page_views  fpl_value fpl_sel  fpl_points  \
# 0               3          12.0         380        5.0   1.30%          60
# 1               1           5.0         504        5.5   0.20%          22
# 2               2           5.0         588        5.5   2.50%           0
# 3               2          35.0        1040        7.0   5.10%          56
# 4               2           6.0         124        5.0   0.00%          38
# ..            ...           ...         ...        ...     ...         ...
# 460             2          15.0         456        5.5   1.40%          91
# 461             3           2.5         263        4.5   0.10%          57
# 462             2           9.0         412        5.5   8.00%         131
# 463             3           1.0         137        4.0  18.80%          26
# 464             4           9.0         285        4.5   6.20%         116
#
#      region nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0         1     England            0        3       20         0            0
# 1         1     England            0        4        7         0            0
# 2         4   Australia            0        3        8         0            0
# 3         1       Wales            0        3        1         1            0
# 4         2      France            0        2       18         0            0
# ..      ...         ...          ...      ...      ...       ...          ...
# 460       2      France            0        4        6         0            0
# 461       2      France            0        4       18         0            1
# 462       2      France            0        4       18         0            0
# 463       2       Spain            0        6       16         0            0
# 464       2      Poland            0        5       16         0            0
#
# [465 rows x 19 columns]

# %%
players.reset_index(inplace=True)

# %%
players.head()
# Out:
#                  name          club  age position  position_cat  market_value  \
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0         380        5.0   1.30%          60       1     England            0
# 1         504        5.5   0.20%          22       1     England            0
# 2         588        5.5   2.50%           0       4   Australia            0
# 3        1040        7.0   5.10%          56       1       Wales            0
# 4         124        5.0   0.00%          38       2      France            0
#
#    age_cat  club_id  big_club  new_signing
# 0        3       20         0            0
# 1        4        7         0            0
# 2        3        8         0            0
# 3        3        1         1            0
# 4        2       18         0            0

# %% [markdown]
# #### Sorting vs. Reordering

# %%
# reindex()

# %%
players_lite = players.iloc[:4, :4]

# %%
players_lite
# Out:
#               name          club  age position
# 0  Aaron Cresswell      West+Ham   27       LB
# 1     Aaron Lennon       Everton   30       RW
# 2       Aaron Mooy  Huddersfield   26       CM
# 3     Aaron Ramsey       Arsenal   26       CM

# %%
# row order: 2, 1, 3, 0
# column order: age, name, position, club

# %%
players_lite.reindex(index=[2,1,3,0], columns=['age', 'name', 'position', 'club'])
# Out:
#    age             name position          club
# 2   26       Aaron Mooy       CM  Huddersfield
# 1   30     Aaron Lennon       RW       Everton
# 3   26     Aaron Ramsey       CM       Arsenal
# 0   27  Aaron Cresswell       LB      West+Ham

# %%
players.reindex(index=[2,1,3,0])
# Out:
#               name          club  age position  position_cat  market_value  \
# 2       Aaron Mooy  Huddersfield   26       CM             2           5.0
# 1     Aaron Lennon       Everton   30       RW             1           5.0
# 3     Aaron Ramsey       Arsenal   26       CM             2          35.0
# 0  Aaron Cresswell      West+Ham   27       LB             3          12.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 2         588        5.5   2.50%           0       4   Australia            0
# 1         504        5.5   0.20%          22       1     England            0
# 3        1040        7.0   5.10%          56       1       Wales            0
# 0         380        5.0   1.30%          60       1     England            0
#
#    age_cat  club_id  big_club  new_signing
# 2        3        8         0            0
# 1        4        7         0            0
# 3        3        1         1            0
# 0        3       20         0            0

# %%
# ...get all the columns, and have them alphabetically ordered

# %%
players.reindex(index=[2,1,3,0]).sort_index(axis=1)
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points fpl_sel  \
# 2   26        3         0  Huddersfield        8           0   2.50%
# 1   30        4         0       Everton        7          22   0.20%
# 3   26        3         1       Arsenal        1          56   5.10%
# 0   27        3         0      West+Ham       20          60   1.30%
#
#    fpl_value  market_value             name nationality  new_foreign  \
# 2        5.5           5.0       Aaron Mooy   Australia            0
# 1        5.5           5.0     Aaron Lennon     England            0
# 3        7.0          35.0     Aaron Ramsey       Wales            0
# 0        5.0          12.0  Aaron Cresswell     England            0
#
#    new_signing  page_views position  position_cat  region
# 2            0         588       CM             2       4
# 1            0         504       RW             1       1
# 3            0        1040       CM             2       1
# 0            0         380       LB             3       1

# %%
players.reindex(index=[2,1,3,0], columns=[])
# Out:
# Empty DataFrame
# Columns: []
# Index: [2, 1, 3, 0]

# %%
# how do we get a sorted list of column labels?

# %%
# ===ASIDE===

# %%
players.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %%
iter(players.columns)

# %%
# iter(True)

# %%
sorted(players.columns)
# Out:
# ['age',
#  'age_cat',
#  'big_club',
#  'club',
#  'club_id',
#  'fpl_points',
#  'fpl_sel',
#  'fpl_value',
#  'market_value',
#  'name',
#  'nationality',
#  'new_foreign',
#  'new_signing',
#  'page_views',
#  'position',
#  'position_cat',
#  'region']

# %%
# ===END ASIDE===

# %%
players.reindex(index=[2,1,3,0], columns=sorted(players.columns)[:6])
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points
# 2   26        3         0  Huddersfield        8           0
# 1   30        4         0       Everton        7          22
# 3   26        3         1       Arsenal        1          56
# 0   27        3         0      West+Ham       20          60

# %% [markdown]
# #### BONUS - Another Way

# %%
players.reindex(index=[2,1,3,0], columns=sorted(players.columns))
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points fpl_sel  \
# 2   26        3         0  Huddersfield        8           0   2.50%
# 1   30        4         0       Everton        7          22   0.20%
# 3   26        3         1       Arsenal        1          56   5.10%
# 0   27        3         0      West+Ham       20          60   1.30%
#
#    fpl_value  market_value             name nationality  new_foreign  \
# 2        5.5           5.0       Aaron Mooy   Australia            0
# 1        5.5           5.0     Aaron Lennon     England            0
# 3        7.0          35.0     Aaron Ramsey       Wales            0
# 0        5.0          12.0  Aaron Cresswell     England            0
#
#    new_signing  page_views position  position_cat  region
# 2            0         588       CM             2       4
# 1            0         504       RW             1       1
# 3            0        1040       CM             2       1
# 0            0         380       LB             3       1

# %%
sorted(players.columns)
# Out:
# ['age',
#  'age_cat',
#  'big_club',
#  'club',
#  'club_id',
#  'fpl_points',
#  'fpl_sel',
#  'fpl_value',
#  'market_value',
#  'name',
#  'nationality',
#  'new_foreign',
#  'new_signing',
#  'page_views',
#  'position',
#  'position_cat',
#  'region']

# %%
players.columns.sort_values()
# Out:
# Index(['age', 'age_cat', 'big_club', 'club', 'club_id', 'fpl_points',
#        'fpl_sel', 'fpl_value', 'market_value', 'name', 'nationality',
#        'new_foreign', 'new_signing', 'page_views', 'position', 'position_cat',
#        'region'],
#       dtype='object')

# %%
players.reindex(index=[2,1,3,0], columns=players.columns.sort_values())
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points fpl_sel  \
# 2   26        3         0  Huddersfield        8           0   2.50%
# 1   30        4         0       Everton        7          22   0.20%
# 3   26        3         1       Arsenal        1          56   5.10%
# 0   27        3         0      West+Ham       20          60   1.30%
#
#    fpl_value  market_value             name nationality  new_foreign  \
# 2        5.5           5.0       Aaron Mooy   Australia            0
# 1        5.5           5.0     Aaron Lennon     England            0
# 3        7.0          35.0     Aaron Ramsey       Wales            0
# 0        5.0          12.0  Aaron Cresswell     England            0
#
#    new_signing  page_views position  position_cat  region
# 2            0         588       CM             2       4
# 1            0         504       RW             1       1
# 3            0        1040       CM             2       1
# 0            0         380       LB             3       1

# %% [markdown]
# #### BONUS: Please Avoid Sorting Like This

# %%
# anti-pattern - please do not do this!!!

# %%
df = players.iloc[:6, :6]

# %%
df
# Out:
#                  name          club  age position  position_cat  market_value
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
# 5       Adam Federici   Bournemouth   32       GK             4           1.0

# %%
df.swapaxes(1, 0)
# Out:
#                             0             1             2             3  \
# name          Aaron Cresswell  Aaron Lennon    Aaron Mooy  Aaron Ramsey
# club                 West+Ham       Everton  Huddersfield       Arsenal
# age                        27            30            26            26
# position                   LB            RW            CM            CM
# position_cat                3             1             2             2
# market_value             12.0           5.0           5.0          35.0
#
#                                4              5
# name          Abdoulaye Doucoure  Adam Federici
# club                     Watford    Bournemouth
# age                           24             32
# position                      CM             GK
# position_cat                   2              4
# market_value                 6.0            1.0

# %%
df.T.sort_index().T
# Out:
#   age          club market_value                name position position_cat
# 0  27      West+Ham         12.0     Aaron Cresswell       LB            3
# 1  30       Everton          5.0        Aaron Lennon       RW            1
# 2  26  Huddersfield          5.0          Aaron Mooy       CM            2
# 3  26       Arsenal         35.0        Aaron Ramsey       CM            2
# 4  24       Watford          6.0  Abdoulaye Doucoure       CM            2
# 5  32   Bournemouth          1.0       Adam Federici       GK            4

# %%
df.sort_index(axis=1)
# Out:
#    age          club  market_value                name position  position_cat
# 0   27      West+Ham          12.0     Aaron Cresswell       LB             3
# 1   30       Everton           5.0        Aaron Lennon       RW             1
# 2   26  Huddersfield           5.0          Aaron Mooy       CM             2
# 3   26       Arsenal          35.0        Aaron Ramsey       CM             2
# 4   24       Watford           6.0  Abdoulaye Doucoure       CM             2
# 5   32   Bournemouth           1.0       Adam Federici       GK             4

# %% [markdown]
# #### Skill Challenge

# %% [markdown]
# ###### **1.**

# %% [markdown]
# Sort the players in the **players** dataframe by age in ascending order. Who is the youngest footballer in the EPL?

# %% [markdown]
# ###### **2**.

# %% [markdown]
# Set the *club* column as the index of the dataframe. Then sort the dataframe index in alphabetical order. Make sure these changes are applied to the underlying dataframe and carry over to the next question.

# %% [markdown]
# ###### **3**.

# %% [markdown]
# Sort the dataframe values by *club* and *market_value* where the club is alphabetical (Arsenal first) and the market value is in descending order (within each team, the most valuable players first).

# %% [markdown]
# #### Solution

# %%
# 1

# %%
players.sort_values(by='age', ascending=True)
# Out:
#                        name               club  age position  position_cat  \
# 53             Ben Woodburn          Liverpool   17       LW             1
# 217           Jonathan Leko          West+Brom   18       RW             1
# 434  Trent Alexander-Arnold          Liverpool   18       RB             3
# 229              Josh Tymon         Stoke+City   18       LB             3
# 45            Axel Tuanzebe  Manchester+United   19       CB             3
# ..                      ...                ...  ...      ...           ...
# 142            Gareth Barry            Everton   36       DM             2
# 90           Damien Delaney     Crystal+Palace   36       CB             3
# 38              Artur Boruc        Bournemouth   37       GK             4
# 143          Gareth McAuley          West+Brom   37       CB             3
# 232          Julian Speroni     Crystal+Palace   38       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 53           1.50        1241        4.5   0.10%           5       1
# 217          1.50         169        4.5   0.20%          12       1
# 434          1.50         327        4.5   0.30%          15       2
# 229          1.00         120        4.5   0.10%           9       1
# 45           1.00         279        4.0   1.70%          14       1
# ..            ...         ...        ...     ...         ...     ...
# 142          1.50        1331        4.5   1.70%          68       1
# 90           1.00         195        4.5   0.60%          51       2
# 38           1.00         436        4.5   6.90%         120       2
# 143          1.00         458        5.0  11.80%         131       2
# 232          0.25         188        4.0   2.00%           0       3
#
#           nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 53              Wales            0        1       10         1            0
# 217           England            0        1       19         0            0
# 434           England            0        1       10         1            0
# 229           England            0        1       15         0            0
# 45            England            0        1       12         1            0
# ..                ...          ...      ...      ...       ...          ...
# 142           England            0        6        7         0            0
# 90            Ireland            0        6        6         0            0
# 38             Poland            0        6        2         0            0
# 143  Northern Ireland            0        6       19         0            0
# 232         Argentina            0        6        6         0            0
#
# [465 rows x 17 columns]

# %%
# idxmin()!

# %%
players.iloc[players.age.idxmin()]
# Out:
# name            Ben Woodburn
# club               Liverpool
# age                       17
# position                  LW
# position_cat               1
# market_value             1.5
# page_views              1241
# fpl_value                4.5
# fpl_sel                0.10%
# fpl_points                 5
# region                     1
# nationality            Wales
# new_foreign                0
# age_cat                    1
# club_id                   10
# big_club                   1
# new_signing                0
# Name: 53, dtype: object

# %%
# 2

# %%
players.set_index('club').sort_index(inplace=True)

# %%
players.head()
# Out:
#                  name          club  age position  position_cat  market_value  \
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0         380        5.0   1.30%          60       1     England            0
# 1         504        5.5   0.20%          22       1     England            0
# 2         588        5.5   2.50%           0       4   Australia            0
# 3        1040        7.0   5.10%          56       1       Wales            0
# 4         124        5.0   0.00%          38       2      France            0
#
#    age_cat  club_id  big_club  new_signing
# 0        3       20         0            0
# 1        4        7         0            0
# 2        3        8         0            0
# 3        3        1         1            0
# 4        2       18         0            0

# %%
# 3

# %%
players.sort_values(by=['club', 'market_value'], ascending=[True, False])
# Out:
#                     name      club  age position  position_cat  market_value  \
# 21        Alexis Sanchez   Arsenal   28       LW             1          65.0
# 306           Mesut Ozil   Arsenal   28       AM             1          50.0
# 20   Alexandre Lacazette   Arsenal   26       CF             1          40.0
# 3           Aaron Ramsey   Arsenal   26       CM             2          35.0
# 152         Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 122  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 384            Sam Byram  West+Ham   23       RB             3           4.5
# 99       Darren Randolph  West+Ham   30       GK             4           2.5
# 179        James Collins  West+Ham   33       CB             3           2.0
# 40       Ashley Fletcher  West+Ham   21       CF             1           1.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 21         4329       12.0  17.10%         264       3        Chile
# 306        4395        9.5   5.60%         167       2      Germany
# 20         1183       10.5  26.50%           0       2       France
# 3          1040        7.0   5.10%          56       1        Wales
# 152        1815        5.5   2.00%          85       2  Switzerland
# ..          ...        ...     ...         ...     ...          ...
# 122         288        4.5   0.40%          38       2  Switzerland
# 384         198        4.5   0.30%          29       1      England
# 99          459        4.5   0.40%          69       2      Ireland
# 179         187        4.5   0.90%          69       2        Wales
# 40          412        4.5   5.90%          16       1      England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 21             0        4        1         1            0
# 306            0        4        1         1            0
# 20             1        3        1         1            0
# 3              0        3        1         1            0
# 152            0        2        1         1            0
# ..           ...      ...      ...       ...          ...
# 122            0        1       20         0            1
# 384            0        2       20         0            0
# 99             0        4       20         0            0
# 179            0        5       20         0            0
# 40             0        1       20         0            1
#
# [465 rows x 17 columns]

# %% [markdown]
# #### Identifying Dupes

# %%
players.head()
# Out:
#                  name          club  age position  position_cat  market_value  \
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0         380        5.0   1.30%          60       1     England            0
# 1         504        5.5   0.20%          22       1     England            0
# 2         588        5.5   2.50%           0       4   Australia            0
# 3        1040        7.0   5.10%          56       1       Wales            0
# 4         124        5.0   0.00%          38       2      France            0
#
#    age_cat  club_id  big_club  new_signing
# 0        3       20         0            0
# 1        4        7         0            0
# 2        3        8         0            0
# 3        3        1         1            0
# 4        2       18         0            0

# %%
players.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players[players.duplicated()]
# Out:
#                         name     club  age position  position_cat  \
# 18   Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 19   Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 154             Granit Xhaka  Arsenal   24       DM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 18           22.0        1519        6.0   1.80%          83       1
# 19           22.0        1519        6.0   1.80%          83       1
# 154          35.0        1815        5.5   2.00%          85       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 18       England            0        2        1         1            0
# 19       England            0        2        1         1            0
# 154  Switzerland            0        2        1         1            0

# %%
# the subset param

# %%
# unique -> club, age, position, market_value

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'])]
# Out:
#                         name               club  age position  position_cat  \
# 18   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 19   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 134                 Fernando    Manchester+City   32       DM             2
# 154             Granit Xhaka            Arsenal   24       DM             2
# 252                Lascelles   Newcastle+United   27       CB             3
# 281              Marcos Rojo  Manchester+United   27       CB             3
# 399              Shane Duffy  Brighton+and+Hove   25       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 18           22.0        1519        6.0   1.80%          83       1
# 19           22.0        1519        6.0   1.80%          83       1
# 134          18.0         338        4.5   0.40%          18       3
# 154          35.0        1815        5.5   2.00%          85       2
# 252           5.0         400        4.5   3.60%           0       1
# 281          18.0        1063        5.5   0.10%          77       3
# 399           5.0         243        4.5   0.60%           0       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 18       England            0        2        1         1            0
# 19       England            0        2        1         1            0
# 134       Brazil            0        5       11         1            0
# 154  Switzerland            0        2        1         1            0
# 252      England            0        3       13         0            0
# 281    Argentina            0        3       12         1            0
# 399      Ireland            0        3        3         0            0

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'])].shape
# Out:
# (7, 17)

# %%
# A - first -> original
# A
# A - last -> original

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'], keep='last')]
# Out:
#                         name               club  age position  position_cat  \
# 17   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 18   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 72            Chris Smalling  Manchester+United   27       CB             3
# 78              Ciaran Clark   Newcastle+United   27       CB             3
# 133              Fernandinho    Manchester+City   32       DM             2
# 152             Granit Xhaka            Arsenal   24       DM             2
# 263               Lewis Dunk  Brighton+and+Hove   25       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 17           22.0        1519        6.0   1.80%          83       1
# 18           22.0        1519        6.0   1.80%          83       1
# 72           18.0         834        5.5   1.30%          52       1
# 78            5.0         273        4.5   0.90%           0       2
# 133          18.0         595        5.0   0.80%          78       3
# 152          35.0        1815        5.5   2.00%          85       2
# 263           5.0         140        4.5   4.10%           0       1
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 17       England            0        2        1         1            0
# 18       England            0        2        1         1            0
# 72       England            0        3       12         1            0
# 78       Ireland            0        3       13         0            0
# 133       Brazil            0        5       11         1            0
# 152  Switzerland            0        2        1         1            0
# 263      England            0        3        3         0            0

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'], keep='last')].shape
# Out:
# (7, 17)

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'], keep=False)]
# Out:
#                         name               club  age position  position_cat  \
# 17   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 18   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 19   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 72            Chris Smalling  Manchester+United   27       CB             3
# 78              Ciaran Clark   Newcastle+United   27       CB             3
# 133              Fernandinho    Manchester+City   32       DM             2
# 134                 Fernando    Manchester+City   32       DM             2
# 152             Granit Xhaka            Arsenal   24       DM             2
# 154             Granit Xhaka            Arsenal   24       DM             2
# 252                Lascelles   Newcastle+United   27       CB             3
# 263               Lewis Dunk  Brighton+and+Hove   25       CB             3
# 281              Marcos Rojo  Manchester+United   27       CB             3
# 399              Shane Duffy  Brighton+and+Hove   25       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 17           22.0        1519        6.0   1.80%          83       1
# 18           22.0        1519        6.0   1.80%          83       1
# 19           22.0        1519        6.0   1.80%          83       1
# 72           18.0         834        5.5   1.30%          52       1
# 78            5.0         273        4.5   0.90%           0       2
# 133          18.0         595        5.0   0.80%          78       3
# 134          18.0         338        4.5   0.40%          18       3
# 152          35.0        1815        5.5   2.00%          85       2
# 154          35.0        1815        5.5   2.00%          85       2
# 252           5.0         400        4.5   3.60%           0       1
# 263           5.0         140        4.5   4.10%           0       1
# 281          18.0        1063        5.5   0.10%          77       3
# 399           5.0         243        4.5   0.60%           0       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 17       England            0        2        1         1            0
# 18       England            0        2        1         1            0
# 19       England            0        2        1         1            0
# 72       England            0        3       12         1            0
# 78       Ireland            0        3       13         0            0
# 133       Brazil            0        5       11         1            0
# 134       Brazil            0        5       11         1            0
# 152  Switzerland            0        2        1         1            0
# 154  Switzerland            0        2        1         1            0
# 252      England            0        3       13         0            0
# 263      England            0        3        3         0            0
# 281    Argentina            0        3       12         1            0
# 399      Ireland            0        3        3         0            0

# %%
players.loc[players.duplicated(subset=['club', 'age', 'position', 'market_value'], keep=False)].shape
# Out:
# (13, 17)

# %% [markdown]
# #### Removing Duplicates

# %%
players[players.duplicated(subset=None, keep='first')]
# Out:
#                         name     club  age position  position_cat  \
# 18   Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 19   Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 154             Granit Xhaka  Arsenal   24       DM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 18           22.0        1519        6.0   1.80%          83       1
# 19           22.0        1519        6.0   1.80%          83       1
# 154          35.0        1815        5.5   2.00%          85       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 18       England            0        2        1         1            0
# 19       England            0        2        1         1            0
# 154  Switzerland            0        2        1         1            0

# %%
players.market_value.mean()
# Out:
# 11.12564935064935

# %%
players.drop_duplicates(keep='first').market_value.mean()
# Out:
# 11.026252723311547

# %%
# duplicates are not necessarily bad!

# %% [markdown]
# #### Removing DataFrame Rows

# %%
players[players.duplicated()]
# Out:
#                         name     club  age position  position_cat  \
# 18   Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 19   Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 154             Granit Xhaka  Arsenal   24       DM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 18           22.0        1519        6.0   1.80%          83       1
# 19           22.0        1519        6.0   1.80%          83       1
# 154          35.0        1815        5.5   2.00%          85       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 18       England            0        2        1         1            0
# 19       England            0        2        1         1            0
# 154  Switzerland            0        2        1         1            0

# %%
players.drop(labels=19, axis=0)
# Out:
#                    name            club  age position  position_cat  \
# 0       Aaron Cresswell        West+Ham   27       LB             3
# 1          Aaron Lennon         Everton   30       RW             1
# 2            Aaron Mooy    Huddersfield   26       CM             2
# 3          Aaron Ramsey         Arsenal   26       CM             2
# 4    Abdoulaye Doucoure         Watford   24       CM             2
# ..                  ...             ...  ...      ...           ...
# 460        Yohan Cabaye  Crystal+Palace   31       CM             2
# 461      YounÃ¨s Kaboul         Watford   31       CB             3
# 462     Ã‰tienne Capoue         Watford   29       DM             2
# 463       Ã€ngel Rangel         Swansea   34       RB             3
# 464  Åukasz FabiaÅ„ski         Swansea   32       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            12.0         380        5.0   1.30%          60       1
# 1             5.0         504        5.5   0.20%          22       1
# 2             5.0         588        5.5   2.50%           0       4
# 3            35.0        1040        7.0   5.10%          56       1
# 4             6.0         124        5.0   0.00%          38       2
# ..            ...         ...        ...     ...         ...     ...
# 460          15.0         456        5.5   1.40%          91       2
# 461           2.5         263        4.5   0.10%          57       2
# 462           9.0         412        5.5   8.00%         131       2
# 463           1.0         137        4.0  18.80%          26       2
# 464           9.0         285        4.5   6.20%         116       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0       England            0        3       20         0            0
# 1       England            0        4        7         0            0
# 2     Australia            0        3        8         0            0
# 3         Wales            0        3        1         1            0
# 4        France            0        2       18         0            0
# ..          ...          ...      ...      ...       ...          ...
# 460      France            0        4        6         0            0
# 461      France            0        4       18         0            1
# 462      France            0        4       18         0            0
# 463       Spain            0        6       16         0            0
# 464      Poland            0        5       16         0            0
#
# [464 rows x 17 columns]

# %%
players.drop(index=19)
# Out:
#                    name            club  age position  position_cat  \
# 0       Aaron Cresswell        West+Ham   27       LB             3
# 1          Aaron Lennon         Everton   30       RW             1
# 2            Aaron Mooy    Huddersfield   26       CM             2
# 3          Aaron Ramsey         Arsenal   26       CM             2
# 4    Abdoulaye Doucoure         Watford   24       CM             2
# ..                  ...             ...  ...      ...           ...
# 460        Yohan Cabaye  Crystal+Palace   31       CM             2
# 461      YounÃ¨s Kaboul         Watford   31       CB             3
# 462     Ã‰tienne Capoue         Watford   29       DM             2
# 463       Ã€ngel Rangel         Swansea   34       RB             3
# 464  Åukasz FabiaÅ„ski         Swansea   32       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            12.0         380        5.0   1.30%          60       1
# 1             5.0         504        5.5   0.20%          22       1
# 2             5.0         588        5.5   2.50%           0       4
# 3            35.0        1040        7.0   5.10%          56       1
# 4             6.0         124        5.0   0.00%          38       2
# ..            ...         ...        ...     ...         ...     ...
# 460          15.0         456        5.5   1.40%          91       2
# 461           2.5         263        4.5   0.10%          57       2
# 462           9.0         412        5.5   8.00%         131       2
# 463           1.0         137        4.0  18.80%          26       2
# 464           9.0         285        4.5   6.20%         116       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0       England            0        3       20         0            0
# 1       England            0        4        7         0            0
# 2     Australia            0        3        8         0            0
# 3         Wales            0        3        1         1            0
# 4        France            0        2       18         0            0
# ..          ...          ...      ...      ...       ...          ...
# 460      France            0        4        6         0            0
# 461      France            0        4       18         0            1
# 462      France            0        4       18         0            0
# 463       Spain            0        6       16         0            0
# 464      Poland            0        5       16         0            0
#
# [464 rows x 17 columns]

# %%
players.drop(index=[19, 20, 21, 231, 10])
# Out:
#                    name            club  age position  position_cat  \
# 0       Aaron Cresswell        West+Ham   27       LB             3
# 1          Aaron Lennon         Everton   30       RW             1
# 2            Aaron Mooy    Huddersfield   26       CM             2
# 3          Aaron Ramsey         Arsenal   26       CM             2
# 4    Abdoulaye Doucoure         Watford   24       CM             2
# ..                  ...             ...  ...      ...           ...
# 460        Yohan Cabaye  Crystal+Palace   31       CM             2
# 461      YounÃ¨s Kaboul         Watford   31       CB             3
# 462     Ã‰tienne Capoue         Watford   29       DM             2
# 463       Ã€ngel Rangel         Swansea   34       RB             3
# 464  Åukasz FabiaÅ„ski         Swansea   32       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            12.0         380        5.0   1.30%          60       1
# 1             5.0         504        5.5   0.20%          22       1
# 2             5.0         588        5.5   2.50%           0       4
# 3            35.0        1040        7.0   5.10%          56       1
# 4             6.0         124        5.0   0.00%          38       2
# ..            ...         ...        ...     ...         ...     ...
# 460          15.0         456        5.5   1.40%          91       2
# 461           2.5         263        4.5   0.10%          57       2
# 462           9.0         412        5.5   8.00%         131       2
# 463           1.0         137        4.0  18.80%          26       2
# 464           9.0         285        4.5   6.20%         116       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0       England            0        3       20         0            0
# 1       England            0        4        7         0            0
# 2     Australia            0        3        8         0            0
# 3         Wales            0        3        1         1            0
# 4        France            0        2       18         0            0
# ..          ...          ...      ...      ...       ...          ...
# 460      France            0        4        6         0            0
# 461      France            0        4       18         0            1
# 462      France            0        4       18         0            0
# 463       Spain            0        6       16         0            0
# 464      Poland            0        5       16         0            0
#
# [460 rows x 17 columns]

# %%
players.shape
# Out:
# (465, 17)

# %% [markdown]
# #### BONUS - Removing Columns

# %%
# "remove rows" -> df.drop(labels=[19, 20], axis=0) or df.drop(index=[19, 20])

# %%
# "remove columns" -> ???

# %%
players.drop(labels=['age', 'market_value'], axis='columns')
# Out:
#                    name            club position  position_cat  page_views  \
# 0       Aaron Cresswell        West+Ham       LB             3         380
# 1          Aaron Lennon         Everton       RW             1         504
# 2            Aaron Mooy    Huddersfield       CM             2         588
# 3          Aaron Ramsey         Arsenal       CM             2        1040
# 4    Abdoulaye Doucoure         Watford       CM             2         124
# ..                  ...             ...      ...           ...         ...
# 460        Yohan Cabaye  Crystal+Palace       CM             2         456
# 461      YounÃ¨s Kaboul         Watford       CB             3         263
# 462     Ã‰tienne Capoue         Watford       DM             2         412
# 463       Ã€ngel Rangel         Swansea       RB             3         137
# 464  Åukasz FabiaÅ„ski         Swansea       GK             4         285
#
#      fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# 0          5.0   1.30%          60       1     England            0        3
# 1          5.5   0.20%          22       1     England            0        4
# 2          5.5   2.50%           0       4   Australia            0        3
# 3          7.0   5.10%          56       1       Wales            0        3
# 4          5.0   0.00%          38       2      France            0        2
# ..         ...     ...         ...     ...         ...          ...      ...
# 460        5.5   1.40%          91       2      France            0        4
# 461        4.5   0.10%          57       2      France            0        4
# 462        5.5   8.00%         131       2      France            0        4
# 463        4.0  18.80%          26       2       Spain            0        6
# 464        4.5   6.20%         116       2      Poland            0        5
#
#      club_id  big_club  new_signing
# 0         20         0            0
# 1          7         0            0
# 2          8         0            0
# 3          1         1            0
# 4         18         0            0
# ..       ...       ...          ...
# 460        6         0            0
# 461       18         0            1
# 462       18         0            0
# 463       16         0            0
# 464       16         0            0
#
# [465 rows x 15 columns]

# %%
players.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %%
players.drop(columns=['age', 'market_value', 'name'])
# Out:
#                club position  position_cat  page_views  fpl_value fpl_sel  \
# 0          West+Ham       LB             3         380        5.0   1.30%
# 1           Everton       RW             1         504        5.5   0.20%
# 2      Huddersfield       CM             2         588        5.5   2.50%
# 3           Arsenal       CM             2        1040        7.0   5.10%
# 4           Watford       CM             2         124        5.0   0.00%
# ..              ...      ...           ...         ...        ...     ...
# 460  Crystal+Palace       CM             2         456        5.5   1.40%
# 461         Watford       CB             3         263        4.5   0.10%
# 462         Watford       DM             2         412        5.5   8.00%
# 463         Swansea       RB             3         137        4.0  18.80%
# 464         Swansea       GK             4         285        4.5   6.20%
#
#      fpl_points  region nationality  new_foreign  age_cat  club_id  big_club  \
# 0            60       1     England            0        3       20         0
# 1            22       1     England            0        4        7         0
# 2             0       4   Australia            0        3        8         0
# 3            56       1       Wales            0        3        1         1
# 4            38       2      France            0        2       18         0
# ..          ...     ...         ...          ...      ...      ...       ...
# 460          91       2      France            0        4        6         0
# 461          57       2      France            0        4       18         0
# 462         131       2      France            0        4       18         0
# 463          26       2       Spain            0        6       16         0
# 464         116       2      Poland            0        5       16         0
#
#      new_signing
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 460            0
# 461            1
# 462            0
# 463            0
# 464            0
#
# [465 rows x 14 columns]

# %% [markdown]
# #### BONUS - Another Way: pop()

# %%
players.pop('age')
# Out:
# 0      27
# 1      30
# 2      26
# 3      26
# 4      24
#        ..
# 460    31
# 461    31
# 462    29
# 463    34
# 464    32
# Name: age, Length: 465, dtype: int64

# %%
# players.pop(['club', 'age'])

# %%
# players.pop('club') and then players.pop('age')

# %%
players.columns
# Out:
# Index(['name', 'club', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %%
players.head(4)
# Out:
#               name          club position  position_cat  market_value  \
# 0  Aaron Cresswell      West+Ham       LB             3          12.0
# 1     Aaron Lennon       Everton       RW             1           5.0
# 2       Aaron Mooy  Huddersfield       CM             2           5.0
# 3     Aaron Ramsey       Arsenal       CM             2          35.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0         380        5.0   1.30%          60       1     England            0
# 1         504        5.5   0.20%          22       1     England            0
# 2         588        5.5   2.50%           0       4   Australia            0
# 3        1040        7.0   5.10%          56       1       Wales            0
#
#    age_cat  club_id  big_club  new_signing
# 0        3       20         0            0
# 1        4        7         0            0
# 2        3        8         0            0
# 3        3        1         1            0

# %% [markdown]
# #### BONUS - A Sophisticated Alternative

# %%
# reindex to remove rows/columns

# %%
players.reindex()
# Out:
#                    name            club position  position_cat  market_value  \
# 0       Aaron Cresswell        West+Ham       LB             3          12.0
# 1          Aaron Lennon         Everton       RW             1           5.0
# 2            Aaron Mooy    Huddersfield       CM             2           5.0
# 3          Aaron Ramsey         Arsenal       CM             2          35.0
# 4    Abdoulaye Doucoure         Watford       CM             2           6.0
# ..                  ...             ...      ...           ...           ...
# 460        Yohan Cabaye  Crystal+Palace       CM             2          15.0
# 461      YounÃ¨s Kaboul         Watford       CB             3           2.5
# 462     Ã‰tienne Capoue         Watford       DM             2           9.0
# 463       Ã€ngel Rangel         Swansea       RB             3           1.0
# 464  Åukasz FabiaÅ„ski         Swansea       GK             4           9.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 0           380        5.0   1.30%          60       1     England
# 1           504        5.5   0.20%          22       1     England
# 2           588        5.5   2.50%           0       4   Australia
# 3          1040        7.0   5.10%          56       1       Wales
# 4           124        5.0   0.00%          38       2      France
# ..          ...        ...     ...         ...     ...         ...
# 460         456        5.5   1.40%          91       2      France
# 461         263        4.5   0.10%          57       2      France
# 462         412        5.5   8.00%         131       2      France
# 463         137        4.0  18.80%          26       2       Spain
# 464         285        4.5   6.20%         116       2      Poland
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 0              0        3       20         0            0
# 1              0        4        7         0            0
# 2              0        3        8         0            0
# 3              0        3        1         1            0
# 4              0        2       18         0            0
# ..           ...      ...      ...       ...          ...
# 460            0        4        6         0            0
# 461            0        4       18         0            1
# 462            0        4       18         0            0
# 463            0        6       16         0            0
# 464            0        5       16         0            0
#
# [465 rows x 16 columns]

# %%
players.reindex(index=[0,3,9])
# Out:
#               name      club position  position_cat  market_value  page_views  \
# 0  Aaron Cresswell  West+Ham       LB             3          12.0         380
# 3     Aaron Ramsey   Arsenal       CM             2          35.0        1040
# 9           Adrian  West+Ham       GK             4           8.0         266
#
#    fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# 0        5.0   1.30%          60       1     England            0        3
# 3        7.0   5.10%          56       1       Wales            0        3
# 9        4.5   0.80%          64       2       Spain            0        4
#
#    club_id  big_club  new_signing
# 0       20         0            0
# 3        1         1            0
# 9       20         0            0

# %%
unwanted_rows = [1,2,3,4]
unwanted_columns = ['name', 'position', 'position_cat']

# %%
players.reindex(
    index=set(players.index).difference(unwanted_rows),
    columns=set(players.columns).difference(unwanted_columns)
    )
# Out:
#      new_foreign  age_cat  fpl_value  big_club            club  region  \
# 0              0        3        5.0         0        West+Ham       1
# 5              0        5        4.0         0     Bournemouth       4
# 6              0        4        7.5         1       Liverpool       1
# 7              0        3        5.0         0     Bournemouth       1
# 8              0        1        5.5         0         Everton       1
# ..           ...      ...        ...       ...             ...     ...
# 460            0        4        5.5         0  Crystal+Palace       2
# 461            0        4        4.5         0         Watford       2
# 462            0        4        5.5         0         Watford       2
# 463            0        6        4.0         0         Swansea       2
# 464            0        5        4.5         0         Swansea       2
#
#      fpl_points  page_views  new_signing  market_value  club_id nationality  \
# 0            60         380            0          12.0       20     England
# 5             8         126            0           1.0        2   Australia
# 6           139        1808            0          25.0       10     England
# 7           104         200            0           5.0        2     England
# 8            16        1387            0           5.0        7     England
# ..          ...         ...          ...           ...      ...         ...
# 460          91         456            0          15.0        6      France
# 461          57         263            1           2.5       18      France
# 462         131         412            0           9.0       18      France
# 463          26         137            0           1.0       16       Spain
# 464         116         285            0           9.0       16      Poland
#
#     fpl_sel
# 0     1.30%
# 5     1.50%
# 6     6.40%
# 7     0.90%
# 8     0.30%
# ..      ...
# 460   1.40%
# 461   0.10%
# 462   8.00%
# 463  18.80%
# 464   6.20%
#
# [461 rows x 13 columns]

# %% [markdown]
# #### Null Values In DataFrames

# %%
players = pd.read_csv('https://andybek.com/pandas-soccer')

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
players.shape
# Out:
# (465, 17)

# %%
# series refresher

# %%
ages = players.age

# %%
type(players.age)
# Out:
# pandas.core.series.Series

# %%
ages.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
ages[ages.isna()]
# Out:
# Series([], Name: age, dtype: int64)

# %%
# dataframes

# %%
players.isna()
# Out:
#       name   club    age  position  position_cat  market_value  page_views  \
# 0    False  False  False     False         False         False       False
# 1    False  False  False     False         False         False       False
# 2    False  False  False     False         False         False       False
# 3    False  False  False     False         False         False       False
# 4    False  False  False     False         False         False       False
# ..     ...    ...    ...       ...           ...           ...         ...
# 460  False  False  False     False         False         False       False
# 461  False  False  False     False         False         False       False
# 462  False  False  False     False         False         False       False
# 463  False  False  False     False         False         False       False
# 464  False  False  False     False         False         False       False
#
#      fpl_value  fpl_sel  fpl_points  region  nationality  new_foreign  \
# 0        False    False       False   False        False        False
# 1        False    False       False   False        False        False
# 2        False    False       False   False        False        False
# 3        False    False       False   False        False        False
# 4        False    False       False   False        False        False
# ..         ...      ...         ...     ...          ...          ...
# 460      False    False       False   False        False        False
# 461      False    False       False   False        False        False
# 462      False    False       False   False        False        False
# 463      False    False       False   False        False        False
# 464      False    False       False   False        False        False
#
#      age_cat  club_id  big_club  new_signing
# 0      False    False     False        False
# 1      False    False     False        False
# 2      False    False     False        False
# 3      False    False     False        False
# 4      False    False     False        False
# ..       ...      ...       ...          ...
# 460    False    False     False        False
# 461    False    False     False        False
# 462    False    False     False        False
# 463    False    False     False        False
# 464    False    False     False        False
#
# [465 rows x 17 columns]

# %%
# how many NAs are there in this dataframe?

# %%
np.count_nonzero(players.isna())
# Out:
# 4

# %%
# which records have NAs in this dataframe?

# %%
players[players.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# #### Dropping And Filling DataFrame NAs

# %%
players.fillna('some meaningful replacement value').loc[[30, 192, 195]]
# Out:
#                   name            club  age  \
# 30        Granit Xhaka         Arsenal   24
# 192       Steve Mounie    Huddersfield   22
# 195  Kasper Schmeichel  Leicester+City   30
#
#                               position  position_cat  \
# 30   some meaningful replacement value             2
# 192                                 CF             1
# 195                                 GK             4
#
#                           market_value  page_views  fpl_value fpl_sel  \
# 30   some meaningful replacement value        1815        5.5   2.00%
# 192  some meaningful replacement value          56        6.0   0.60%
# 195  some meaningful replacement value        1601        5.0   2.40%
#
#      fpl_points  region  nationality  new_foreign  age_cat  club_id  big_club  \
# 30           85       2  Switzerland            0        2        1         1
# 192           0       2        Benin            0        2        8         0
# 195         109       2      Denmark            0        4        9         0
#
#      new_signing
# 30             0
# 192            0
# 195            0

# %%
players.fillna({
    'market_value': 100,
    'position': 'RM'
}).loc[[30, 192, 195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       RM             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30          100.0        1815        5.5   2.00%          85       2
# 192         100.0          56        6.0   0.60%           0       2
# 195         100.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.fillna({
    'market_value': players.market_value.mean(),
    'position': 'RM'
}).loc[[30, 192, 195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       RM             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30      11.125649        1815        5.5   2.00%          85       2
# 192     11.125649          56        6.0   0.60%           0       2
# 195     11.125649        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
# how about dropping nulls?

# %%
players.dropna(axis=1, how='all').loc[[30, 192, 195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# #### BONUS - Method And Axes With fillna()

# %%
players[players.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
# players.fillna('some meaningful replacement value').loc[[30, 192, 195]]

# players.fillna({ 'market_value': 100, 'position': 'RM' }).loc[[30, 192, 195]]

# %%
players.fillna(method='ffill').loc[[29, 30, 191, 192, 194, 195]]
# Out:
#                   name            club  age position  position_cat  \
# 29      Sead Kolasinac         Arsenal   24       LB             3
# 30        Granit Xhaka         Arsenal   24       LB             2
# 191   Laurent Depoitre    Huddersfield   28       CF             1
# 192       Steve Mounie    Huddersfield   22       CF             1
# 194       Riyad Mahrez  Leicester+City   26       RW             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 30           15.0        1815        5.5   2.00%          85       2
# 191           3.0         212        5.5   0.30%           0       2
# 192           3.0          56        6.0   0.60%           0       2
# 194          30.0        1753        8.5   1.70%         120       4
# 195          30.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29        Bosnia            1        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# 191      Belgium            0        4        8         0            0
# 192        Benin            0        2        8         0            0
# 194      Algeria            0        3        9         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna(method='ffill', axis=0).loc[[29, 30, 191, 192, 194, 195]]
# Out:
#                   name            club  age position  position_cat  \
# 29      Sead Kolasinac         Arsenal   24       LB             3
# 30        Granit Xhaka         Arsenal   24       LB             2
# 191   Laurent Depoitre    Huddersfield   28       CF             1
# 192       Steve Mounie    Huddersfield   22       CF             1
# 194       Riyad Mahrez  Leicester+City   26       RW             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 30           15.0        1815        5.5   2.00%          85       2
# 191           3.0         212        5.5   0.30%           0       2
# 192           3.0          56        6.0   0.60%           0       2
# 194          30.0        1753        8.5   1.70%         120       4
# 195          30.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29        Bosnia            1        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# 191      Belgium            0        4        8         0            0
# 192        Benin            0        2        8         0            0
# 194      Algeria            0        3        9         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna(method='pad', axis=1).loc[[30, 192, 195]]
# Out:
#                   name            club age position position_cat market_value  \
# 30        Granit Xhaka         Arsenal  24       24            2            2
# 192       Steve Mounie    Huddersfield  22       CF            1            1
# 195  Kasper Schmeichel  Leicester+City  30       GK            4            4
#
#     page_views fpl_value fpl_sel fpl_points region  nationality new_foreign  \
# 30        1815       5.5   2.00%         85      2  Switzerland           0
# 192         56       6.0   0.60%          0      2        Benin           0
# 195       1601       5.0   2.40%        109      2      Denmark           0
#
#     age_cat club_id big_club new_signing
# 30        2       1        1           0
# 192       2       8        0           0
# 195       4       9        0           0

# %%
# 'ffill' -> 'pad'
# 'bfill' -> 'backfill'

# %%
# word of the lecture: duo -> pair

# %% [markdown]
# #### Skill Challenge

# %% [markdown]
# ###### **1**.

# %% [markdown]
# From our *players* dataframe remove the rows labeled 2, 10, 21 and the market_value columns. Do not modify the underlying dataframe. Assign the result to _df2_.

# %% [markdown]
# ###### **2**.

# %% [markdown]
# Does the _nationality_ column in _df2_ contain any NA values? How many unique nationalities are there?

# %% [markdown]
# ###### **3**.

# %% [markdown]
# Starting from _df2_, isolate a dataframe slice of players that contains only the unique _age_-_position_ combinations for each _club_. Do not include the _club_ column itself.

# %% [markdown]
# #### Solution

# %%
players.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
# 1

# %%
df2 = players.drop(labels=[2,10,21], axis=0)\
       .drop(labels='market_value', axis=1)

# %%
# alternative
players.drop(index=[2, 10, 21], columns='market_value')
# Out:
#                     name      club  age position  position_cat  page_views  \
# 0         Alexis Sanchez   Arsenal   28       LW             1        4329
# 1             Mesut Ozil   Arsenal   28       AM             1        4395
# 3           Theo Walcott   Arsenal   28       RW             1        2393
# 4      Laurent Koscielny   Arsenal   31       CB             3         912
# 5        Hector Bellerin   Arsenal   22       RB             3        1675
# ..                   ...       ...  ...      ...           ...         ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2         288
# 461       Arthur Masuaku  West+Ham   23       LB             3         199
# 462            Sam Byram  West+Ham   23       RB             3         198
# 463      Ashley Fletcher  West+Ham   21       CF             1         412
# 464         Diafra Sakho  West+Ham   27       CF             1         214
#
#      fpl_value fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  \
# 0         12.0  17.10%         264       3        Chile            0        4
# 1          9.5   5.60%         167       2      Germany            0        4
# 3          7.5   1.50%         122       1      England            0        4
# 4          6.0   0.70%         121       2       France            0        4
# 5          6.0  13.70%         119       2        Spain            0        2
# ..         ...     ...         ...     ...          ...          ...      ...
# 460        4.5   0.40%          38       2  Switzerland            0        1
# 461        4.5   0.20%          34       4     Congo DR            0        2
# 462        4.5   0.30%          29       1      England            0        2
# 463        4.5   5.90%          16       1      England            0        1
# 464        5.5   0.10%          12       4      Senegal            0        3
#
#      club_id  big_club  new_signing
# 0          1         1            0
# 1          1         1            0
# 3          1         1            0
# 4          1         1            0
# 5          1         1            0
# ..       ...       ...          ...
# 460       20         0            1
# 461       20         0            1
# 462       20         0            0
# 463       20         0            1
# 464       20         0            0
#
# [462 rows x 16 columns]

# %%
# 2

# %%
df2.nationality.isnull().sum()
# Out:
# 0

# %%
df2.nationality[df2.nationality.isnull()]
# Out:
# Series([], Name: nationality, dtype: object)

# %%
# how many uniques

# %%
df2.nationality.drop_duplicates().size
# Out:
# 61

# %%
# an alternative

# %%
df2.nationality.nunique()
# Out:
# 61

# %%
# 3

# %%
df2.drop_duplicates(subset=['age', 'club', 'position'], keep='first').loc[:, ['age', 'position']]
# Out:
#      age position
# 0     28       LW
# 1     28       AM
# 3     28       RW
# 4     31       CB
# 5     22       RB
# ..   ...      ...
# 460   21       CM
# 461   23       LB
# 462   23       RB
# 463   21       CF
# 464   27       CF
#
# [433 rows x 2 columns]

# %%
df2.shape
# Out:
# (462, 16)

# %% [markdown]
# #### Calculating Aggregates With agg()

# %%
players.agg('mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[316], line 1
# ----> 1 players.agg('mean')
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:9196, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#    9193 relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    9195 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9196 result = op.agg()
#    9198 if relabeling:
#    9199     # This is to keep the order to columns occurrence unchanged, and also
#    9200     # keep the order of new columns occurrence unchanged
#    9201
#    9202     # For the return values of reconstruct_func, if relabeling is
#    9203     # False, columns and order will be None.
#    9204     assert columns is not None
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:690, in FrameApply.agg(self)
#     688 result = None
#     689 try:
# --> 690     result = super().agg()
#     691 finally:
#     692     self.obj = obj
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:851, in FrameApply.apply_str(self)
#     849     value = obj.shape[self.axis]
#     850     return obj._constructor_sliced(value, index=self.agg_axis)
# --> 851 return super().apply_str()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
players.new_signing.mean()

# %%
players.agg(np.min)

# %%
# ===ASIDE

# %%
# >, <, <=, >= should have some meaning

# %%
'a' < 'b'

# %%
ord('a')
# Out:
# 97

# %%
ord('b')
# Out:
# 98

# %%
ls = ['a', 'b', 'c', 'day', 19]

# %%
# max(ls)

# %%
ord('d')
# Out:
# 100

# %%
# ===END ASIDE

# %%
players.agg('min')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[323], line 1
# ----> 1 players.agg('min')
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:9196, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#    9193 relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    9195 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9196 result = op.agg()
#    9198 if relabeling:
#    9199     # This is to keep the order to columns occurrence unchanged, and also
#    9200     # keep the order of new columns occurrence unchanged
#    9201
#    9202     # For the return values of reconstruct_func, if relabeling is
#    9203     # False, columns and order will be None.
#    9204     assert columns is not None
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:690, in FrameApply.agg(self)
#     688 result = None
#     689 try:
# --> 690     result = super().agg()
#     691 finally:
#     692     self.obj = obj
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:851, in FrameApply.apply_str(self)
#     849     value = obj.shape[self.axis]
#     850     return obj._constructor_sliced(value, index=self.agg_axis)
# --> 851 return super().apply_str()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11669, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, numeric_only, **kwargs)
#   11650 @doc(
#   11651     _num_doc,
#   11652     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11667     **kwargs,
#   11668 ):
# > 11669     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11169, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11162 def min(
#   11163     self,
#   11164     axis: Axis | None = 0,
#    (...)
#   11167     **kwargs,
#   11168 ):
# > 11169     return self._stat_function(
#   11170         "min",
#   11171         nanops.nanmin,
#   11172         axis,
#   11173         skipna,
#   11174         numeric_only,
#   11175         **kwargs,
#   11176     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:1094, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1092         result = np.nan
#    1093 else:
# -> 1094     result = getattr(values, meth)(axis)
#    1096 result = _maybe_null_out(result, axis, mask, values.shape)
#    1097 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'str' and 'float'

# %%
players.select_dtypes(np.number).agg('min')
# Out:
# age             17.00
# position_cat     1.00
# market_value     0.05
# page_views       3.00
# fpl_value        4.00
# fpl_points       0.00
# region           1.00
# new_foreign      0.00
# age_cat          1.00
# club_id          1.00
# big_club         0.00
# new_signing      0.00
# dtype: float64

# %%
players.select_dtypes(np.number).agg(['min', 'max', 'mean'])
# Out:
#             age  position_cat  market_value   page_views  fpl_value  \
# min   17.000000      1.000000      0.050000     3.000000   4.000000
# max   38.000000      4.000000     75.000000  7664.000000  12.500000
# mean  26.776344      2.178495     11.125649   771.546237   5.450538
#
#       fpl_points    region  new_foreign   age_cat    club_id  big_club  \
# min     0.000000  1.000000     0.000000  1.000000   1.000000  0.000000
# max   264.000000  4.000000     1.000000  6.000000  20.000000  1.000000
# mean   57.544086  1.989247     0.034409  3.195699  10.253763  0.309677
#
#       new_signing
# min      0.000000
# max      1.000000
# mean     0.144086

# %% [markdown]
# #### Same-shape Transforms

# %%
players.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
# 2       Petr Cech  Arsenal   35       GK             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0

# %%
# we need an fx rate

# %%
# usdeur = 0.91

# %%
players.loc[:, ['market_value', 'fpl_value']]
# Out:
#      market_value  fpl_value
# 0            65.0       12.0
# 1            50.0        9.5
# 2             7.0        5.5
# 3            20.0        7.5
# 4            22.0        6.0
# ..            ...        ...
# 460           5.0        4.5
# 461           7.0        4.5
# 462           4.5        4.5
# 463           1.0        4.5
# 464          10.0        5.5
#
# [465 rows x 2 columns]

# %%
players.loc[:, ['market_value', 'fpl_value']].transform(lambda x: x * 0.91)
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %%
players.loc[:, ['market_value', 'fpl_value']] * 0.91
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %%
# ===ASIDE

# %%
# 1. choice

# %%
from random import choice

# %%
names = ['Bud', 'Brooke', 'Paleo']

# %%
choice(names)
# Out:
# 'Brooke'

# %%
# 2. str methods

# %%
'Andy'.upper()
# Out:
# 'ANDY'

# %%
ser = pd.Series(['Bud CriMSon', 'Brooke', 'Paleo'])

# %%
ser.str.upper()
# Out:
# 0    BUD CRIMSON
# 1         BROOKE
# 2          PALEO
# dtype: object

# %%
ser.str.title()
# Out:
# 0    Bud Crimson
# 1         Brooke
# 2          Paleo
# dtype: object

# %%
ser.str.swapcase()
# Out:
# 0    bUD cRImsON
# 1         bROOKE
# 2          pALEO
# dtype: object

# %%
# ===END ASIDE

# %%
# the function should:
# - apply a random string capitalization method
# - to a sequence of values, and
# - return the transformed sequence

# %%
def random_case(x):
  funcs = [x.str.swapcase, x.str.lower, x.str.title, x.str.upper]

  return choice(funcs)()

# %%
for i in range(4):
  print(players.select_dtypes(include=object).transform(random_case).head())
# Out:
#                 name     club position fpl_sel     nationality
# 0     alexis sanchez  arsenal       Lw  17.10%           CHILE
# 1         mesut ozil  arsenal       Am   5.60%         GERMANY
# 2          petr cech  arsenal       Gk   5.90%  CZECH REPUBLIC
# 3       theo walcott  arsenal       Rw   1.50%         ENGLAND
# 4  laurent koscielny  arsenal       Cb   0.70%          FRANCE
#                 name     club position fpl_sel     nationality
# 0     aLEXIS sANCHEZ  Arsenal       Lw  17.10%           chile
# 1         mESUT oZIL  Arsenal       Am   5.60%         germany
# 2          pETR cECH  Arsenal       Gk   5.90%  czech republic
# 3       tHEO wALCOTT  Arsenal       Rw   1.50%         england
# 4  lAURENT kOSCIELNY  Arsenal       Cb   0.70%          france
#                 name     club position fpl_sel     nationality
# 0     ALEXIS SANCHEZ  ARSENAL       lw  17.10%           Chile
# 1         MESUT OZIL  ARSENAL       am   5.60%         Germany
# 2          PETR CECH  ARSENAL       gk   5.90%  Czech Republic
# 3       THEO WALCOTT  ARSENAL       rw   1.50%         England
# 4  LAURENT KOSCIELNY  ARSENAL       cb   0.70%          France
#                 name     club position fpl_sel     nationality
# 0     Alexis Sanchez  Arsenal       LW  17.10%           Chile
# 1         Mesut Ozil  Arsenal       AM   5.60%         Germany
# 2          Petr Cech  Arsenal       GK   5.90%  Czech Republic
# 3       Theo Walcott  Arsenal       RW   1.50%         England
# 4  Laurent Koscielny  Arsenal       CB   0.70%          France

# %% [markdown]
# #### More Flexibility With apply()

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
def round_floats(x):
  if x.dtype == np.float64:
    return round(x)

  return x

# %%
players.apply(round_floats)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.0
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0          4329       12.0  17.10%         264       3           Chile
# 1          4395       10.0   5.60%         167       2         Germany
# 2          1529        6.0   5.90%         134       2  Czech Republic
# 3          2393        8.0   1.50%         122       1         England
# 4           912        6.0   0.70%         121       2          France
# ..          ...        ...     ...         ...     ...             ...
# 460         288        4.0   0.40%          38       2     Switzerland
# 461         199        4.0   0.20%          34       4        Congo DR
# 462         198        4.0   0.30%          29       1         England
# 463         412        4.0   5.90%          16       1         England
# 464         214        6.0   0.10%          12       4         Senegal
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 0              0        4        1         1            0
# 1              0        4        1         1            0
# 2              0        6        1         1            0
# 3              0        4        1         1            0
# 4              0        4        1         1            0
# ..           ...      ...      ...       ...          ...
# 460            0        1       20         0            1
# 461            0        2       20         0            1
# 462            0        2       20         0            0
# 463            0        1       20         0            1
# 464            0        3       20         0            0
#
# [465 rows x 17 columns]

# %%
players.select_dtypes(np.float64).head()
# Out:
#    market_value  fpl_value
# 0          65.0       12.0
# 1          50.0        9.5
# 2           7.0        5.5
# 3          20.0        7.5
# 4          22.0        6.0

# %%
players.select_dtypes(np.float64).apply(round_floats).head()
# Out:
#    market_value  fpl_value
# 0          65.0       12.0
# 1          50.0       10.0
# 2           7.0        6.0
# 3          20.0        8.0
# 4          22.0        6.0

# %%
# apply() = agg() + transfroms()

# %%
# apply as aggregate

# %%
players.agg('mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[354], line 1
# ----> 1 players.agg('mean')
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:9196, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#    9193 relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    9195 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9196 result = op.agg()
#    9198 if relabeling:
#    9199     # This is to keep the order to columns occurrence unchanged, and also
#    9200     # keep the order of new columns occurrence unchanged
#    9201
#    9202     # For the return values of reconstruct_func, if relabeling is
#    9203     # False, columns and order will be None.
#    9204     assert columns is not None
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:690, in FrameApply.agg(self)
#     688 result = None
#     689 try:
# --> 690     result = super().agg()
#     691 finally:
#     692     self.obj = obj
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:851, in FrameApply.apply_str(self)
#     849     value = obj.shape[self.axis]
#     850     return obj._constructor_sliced(value, index=self.agg_axis)
# --> 851 return super().apply_str()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
players.apply('mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[355], line 1
# ----> 1 players.apply('mean')
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:657, in FrameApply.apply(self)
#     655 # string dispatch
#     656 if isinstance(self.f, str):
# --> 657     return self.apply_str()
#     659 # ufunc
#     660 elif isinstance(self.f, np.ufunc):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:851, in FrameApply.apply_str(self)
#     849     value = obj.shape[self.axis]
#     850     return obj._constructor_sliced(value, index=self.agg_axis)
# --> 851 return super().apply_str()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# players.transform('mean')

# %%
# flipping the axis param

# %%
players.apply('mean', axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[358], line 1
# ----> 1 players.apply('mean', axis=0)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:657, in FrameApply.apply(self)
#     655 # string dispatch
#     656 if isinstance(self.f, str):
# --> 657     return self.apply_str()
#     659 # ufunc
#     660 elif isinstance(self.f, np.ufunc):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:851, in FrameApply.apply_str(self)
#     849     value = obj.shape[self.axis]
#     850     return obj._constructor_sliced(value, index=self.agg_axis)
# --> 851 return super().apply_str()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
players.age.mean()
# Out:
# 26.776344086021506

# %%
players.apply('mean', axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[360], line 1
# ----> 1 players.apply('mean', axis=1)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:657, in FrameApply.apply(self)
#     655 # string dispatch
#     656 if isinstance(self.f, str):
# --> 657     return self.apply_str()
#     659 # ufunc
#     660 elif isinstance(self.f, np.ufunc):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:851, in FrameApply.apply_str(self)
#     849     value = obj.shape[self.axis]
#     850     return obj._constructor_sliced(value, index=self.agg_axis)
# --> 851 return super().apply_str()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/homebrew/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# players.loc[460, :].mean()

# %%
players.loc[460, [dtype != object for dtype in players.dtypes]].mean()
# Out:
# 31.875

# %% [markdown]
# #### Element-wise Operations With applymap()

# %%
# vectorized ops: agg(), transform(), apply()

# %%
# non-vectorized: applymap()

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# 1            0        4        1         1            0
# 2            0        6        1         1            0
# 3            0        4        1         1            0
# 4            0        4        1         1            0

# %%
# ~2%/year

# %%
inflation = 1.02

# %%
mini_df = players.loc[:, ['market_value', 'fpl_value']]

# %%
mini_df * inflation
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %%
from datetime import datetime
counter = 0

def log_and_transform(x):
  global counter
  counter += 1
  if counter % 100 == 0:
    print(f"It's {datetime.now()} and I just adjusted the {counter}th value.")
    # print("It's {} and I just adjusted the {}th value.".format(datetime.now(), counter))
  
  return x * inflation

# %%
import sys
sys.version
# Out:
# '3.11.4 (main, Jun 20 2023, 17:23:00) [Clang 14.0.3 (clang-1403.0.22.14.1)]'

# %%
mini_df.apply(log_and_transform)
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %%
mini_df.applymap(log_and_transform)
# Out:
# It's 2023-08-25 09:56:27.377377 and I just adjusted the 100th value.
# It's 2023-08-25 09:56:27.377406 and I just adjusted the 200th value.
# It's 2023-08-25 09:56:27.377419 and I just adjusted the 300th value.
# It's 2023-08-25 09:56:27.377430 and I just adjusted the 400th value.
# It's 2023-08-25 09:56:27.377529 and I just adjusted the 500th value.
# It's 2023-08-25 09:56:27.377542 and I just adjusted the 600th value.
# It's 2023-08-25 09:56:27.377553 and I just adjusted the 700th value.
# It's 2023-08-25 09:56:27.377564 and I just adjusted the 800th value.
# It's 2023-08-25 09:56:27.377575 and I just adjusted the 900th value.
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %% [markdown]
# #### Skill Challenge

# %% [markdown]
# ###### **1.**

# %% [markdown]
# Create a standalone function that
# - accepts a single parameter x
# - returns the string 'relatively unknown' if x is less than 220
# - 'kind of popular' if x is between 220 and 600 (non-inclusive)
# - 'popular' if x is between 600 and 2000 (non-inclusive)
# - 'super-popular' otherwise
#
# | lower bound | upper bound (non-inclusive) | popularity label     |
# |-------------|-----------------------------|----------------------|
# | -inf        | 220                         | 'relatively unknown' |
# | 220         | 600                         | 'kind of popular'    |
# | 600         | 2000                        | 'popular'            |
# | 2000        | +inf                        | 'super-popular'      |

# %% [markdown]
# ###### **2.**

# %% [markdown]
# Apply the function from the step above to the players _page_views_ column. Use a method that supports vectorized operations.

# %% [markdown]
# ###### **3.**

# %% [markdown]
# Add the output from the step above as a new column to the _players_ dataframe. Name the column _popularity_.

# %% [markdown]
# ###### **4.**

# %% [markdown]
# How many "super-popular" players are there?

# %% [markdown]
# #### Solution

# %%
# 1

# %%
def get_popularity(x):
  if x < 220:
    return 'relatively unknown'
  elif x < 600:
    return 'kind of popular'
  elif x < 2000:
    return 'popular'
  else:
    return 'super-popular'

# %%
get_popularity(1)
# Out:
# 'relatively unknown'

# %%
get_popularity(1000)
# Out:
# 'popular'

# %%
get_popularity(10000)
# Out:
# 'super-popular'

# %%
# 2

# %%
players.page_views.head()
# Out:
# 0    4329
# 1    4395
# 2    1529
# 3    2393
# 4     912
# Name: page_views, dtype: int64

# %%
players.page_views.apply(get_popularity)
# Out:
# 0           super-popular
# 1           super-popular
# 2                 popular
# 3           super-popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464    relatively unknown
# Name: page_views, Length: 465, dtype: object

# %%
# 3

# %%
players['popularity'] = players.page_views.apply(get_popularity)

# %%
players.popularity
# Out:
# 0           super-popular
# 1           super-popular
# 2                 popular
# 3           super-popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464    relatively unknown
# Name: popularity, Length: 465, dtype: object

# %%
# 4

# %%
players.popularity.value_counts()
# Out:
# popularity
# kind of popular       170
# popular               143
# relatively unknown    115
# super-popular          37
# Name: count, dtype: int64

# %%
players[players.popularity == 'super-popular'].name.size
# Out:
# 37

# %% [markdown]
# #### Setting DataFrame Values

# %%
players.head(10)
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
# 5    Hector Bellerin  Arsenal   22       RB             3          30.0
# 6     Olivier Giroud  Arsenal   30       CF             1          22.0
# 7      Nacho Monreal  Arsenal   31       LB             3          13.0
# 8   Shkodran Mustafi  Arsenal   25       CB             3          30.0
# 9         Alex Iwobi  Arsenal   21       LW             1          10.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
# 5        1675        6.0  13.70%         119       2           Spain
# 6        2230        8.5   2.50%         116       2          France
# 7         555        5.5   4.70%         115       2           Spain
# 8        1877        5.5   4.00%          90       2         Germany
# 9        1812        5.5   1.00%          89       4         Nigeria
#
#    new_foreign  age_cat  club_id  big_club  new_signing       popularity
# 0            0        4        1         1            0    super-popular
# 1            0        4        1         1            0    super-popular
# 2            0        6        1         1            0          popular
# 3            0        4        1         1            0    super-popular
# 4            0        4        1         1            0          popular
# 5            0        2        1         1            0          popular
# 6            0        4        1         1            0    super-popular
# 7            0        4        1         1            0  kind of popular
# 8            0        3        1         1            1          popular
# 9            0        1        1         1            0          popular

# %%
# %%timeit
players.loc[3, 'position'] = 'CM'
# Out:
# 17.9 µs ± 530 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
355/5.73
# Out:
# 61.95462478184991

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       CM             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular

# %%
# %%timeit
players.iloc[3, 3] = 'RW'
# Out:
# 14.8 µs ± 120 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# at[] and iat[] should be preferred for single value assignment

# %%
# %%timeit
players.at[3, 'position'] = 'CM'
# Out:
# 3.2 µs ± 30.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       CM             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular

# %%
# %%timeit
players.iat[3, 3] = 'RW'
# Out:
# 2.47 µs ± 20 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# #### The SettingWithCopy Warning

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular

# %%
players['page_views'][2] = 2001
# Out:
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/1383370597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['page_views'][2] = 2001

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular

# %%
players.drop_duplicates()['page_views'][2] = 3000
# Out:
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/1701671751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players.drop_duplicates()['page_views'][2] = 3000

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular

# %%
pd.options.mode.chained_assignment = 'warn'

# %%
# 'None' -> turns the SettingWithCopyWarning off

# %% [markdown]
# #### View vs Copy

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular

# %%
players.loc[0:3, 'position'] = ['CM', 'RW', 'CB', 'GK']

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular

# %%
# Aaron -> nickname

# %%
players.loc[players.name.str.startswith('Aaron')]
# Out:
# Empty DataFrame
# Columns: [name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing, popularity]
# Index: []

# %%
players.loc[players.name.str.startswith('Aaron'), 'name'] = 'Ronny'

# %%
players.loc[[15, 157, 176, 455]]
# Out:
#       name          club age position  position_cat  market_value  page_views  \
# 15   Ronny       Arsenal  26       CM             2          35.0        1040
# 157  Ronny       Everton  30       RW             1           5.0         504
# 176  Ronny  Huddersfield  26       CM             2           5.0         588
# 455  Ronny      West+Ham  27       LB             3          12.0         380
#
#      fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# 15         7.0   5.10%          56       1       Wales            0        3
# 157        5.5   0.20%          22       1     England            0        4
# 176        5.5   2.50%           0       4   Australia            0        3
# 455        5.0   1.30%          60       1     England            0        3
#
#      club_id  big_club  new_signing       popularity
# 15         1         1            0          popular
# 157        7         0            0  kind of popular
# 176        8         0            0  kind of popular
# 455       20         0            0  kind of popular

# %%
# do not do this!

# %%
players['age'].iloc[1] = '12'
# Out:
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/3319155415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['age'].iloc[1] = '12'

# %%
players.drop_duplicates().loc[3, 'position'] = 'CM'

# %% [markdown]
# #### Adding DataFrame Columns

# %%
players.popularity
# Out:
# 0           super-popular
# 1           super-popular
# 2                 popular
# 3           super-popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464    relatively unknown
# Name: popularity, Length: 465, dtype: object

# %%
'MVtoFPL' in players
# Out:
# False

# %%
'popularity' in players
# Out:
# True

# %%
players['MVtoFPL'] = 1.0

# %%
'MVtoFPL' in players
# Out:
# True

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity  \
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular
#
#    MVtoFPL
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0

# %%
players['MVtoFPL'] = players['market_value'] / players['fpl_value']

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity  \
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular
#
#     MVtoFPL
# 0  5.416667
# 1  5.263158
# 2  1.272727
# 3  2.666667
# 4  3.666667

# %%
df_mini = players.iloc[:4, 1:5]

# %%
df_mini
# Out:
#       club age position  position_cat
# 0  Arsenal  28       CM             1
# 1  Arsenal  12       RW             1
# 2  Arsenal  35       CB             4
# 3  Arsenal  28       GK             1

# %%
player_names = pd.Series(['Bronson', 'Bradley', 'Ronald', 'Ronny'])

# %%
player_names
# Out:
# 0    Bronson
# 1    Bradley
# 2     Ronald
# 3      Ronny
# dtype: object

# %%
df_mini.insert(0, 'nicknames', player_names)

# %%
df_mini
# Out:
#   nicknames     club age position  position_cat
# 0   Bronson  Arsenal  28       CM             1
# 1   Bradley  Arsenal  12       RW             1
# 2    Ronald  Arsenal  35       CB             4
# 3     Ronny  Arsenal  28       GK             1

# %%
# the assign() approach

# %%
df_mini.assign(career_goals=[12 ,67, 179, 49], nationality=['American', 'British', 'Turkish', 'Indian'])
# Out:
#   nicknames     club age position  position_cat  career_goals nationality
# 0   Bronson  Arsenal  28       CM             1            12    American
# 1   Bradley  Arsenal  12       RW             1            67     British
# 2    Ronald  Arsenal  35       CB             4           179     Turkish
# 3     Ronny  Arsenal  28       GK             1            49      Indian

# %%
df_mini
# Out:
#   nicknames     club age position  position_cat
# 0   Bronson  Arsenal  28       CM             1
# 1   Bradley  Arsenal  12       RW             1
# 2    Ronald  Arsenal  35       CB             4
# 3     Ronny  Arsenal  28       GK             1

# %% [markdown]
# #### Adding Rows To DataFrames

# %%
df_mini
# Out:
#   nicknames     club age position  position_cat
# 0   Bronson  Arsenal  28       CM             1
# 1   Bradley  Arsenal  12       RW             1
# 2    Ronald  Arsenal  35       CB             4
# 3     Ronny  Arsenal  28       GK             1

# %%
# the append() method -> series, dfs, or a collection of them

# %%
cristiano = pd.Series({
    'nicknames': 'Cristiano',
    'age': 32,
    'position': 'RW',
    'club': 'Juventus',
    'position_cat': 1
}, name=4)

# %%
cristiano
# Out:
# nicknames       Cristiano
# age                    32
# position               RW
# club             Juventus
# position_cat            1
# Name: 4, dtype: object

# %%
df_mini = df_mini.append(cristiano)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/2266654051.py in ?()
# ----> 1 df_mini = df_mini.append(cristiano)
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# df_mini.append([player_1, player_2, player_3...])

# %%
other_players = pd.DataFrame({
    'nicknames': ['Gianluigi', 'Lionel'],
    'age': [37, 32],
    'club': ['Juventus', 'Barcelona'],
    'position': ['GK', 'CF'],
    'position_cat': [4,2]
}, index=[5,6])

# %%
other_players
# Out:
#    nicknames  age       club position  position_cat
# 5  Gianluigi   37   Juventus       GK             4
# 6     Lionel   32  Barcelona       CF             2

# %%
df_mini = df_mini.append(other_players)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/384630530.py in ?()
# ----> 1 df_mini = df_mini.append(other_players)
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# setting with enlargement

# %%
# df['inexistent label'] = 'some value'

# %%
df_mini
# Out:
#   nicknames     club age position  position_cat
# 0   Bronson  Arsenal  28       CM             1
# 1   Bradley  Arsenal  12       RW             1
# 2    Ronald  Arsenal  35       CB             4
# 3     Ronny  Arsenal  28       GK             1

# %%
df_mini.loc[9] = 'some row value'

# %%
df_mini
# Out:
#         nicknames            club             age        position  \
# 0         Bronson         Arsenal              28              CM
# 1         Bradley         Arsenal              12              RW
# 2          Ronald         Arsenal              35              CB
# 3           Ronny         Arsenal              28              GK
# 9  some row value  some row value  some row value  some row value
#
#      position_cat
# 0               1
# 1               1
# 2               4
# 3               1
# 9  some row value

# %%
# adding rows to dataframes is inefficient (a very expensive operation)

# %% [markdown]
# #### BONUS - How Are DataFrames Stored In Memory

# %%
players.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 19 entries, name to MVtoFPL
# dtypes: float64(3), int64(9), object(7)
# memory usage: 69.2+ KB

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity  \
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular
#
#     MVtoFPL
# 0  5.416667
# 1  5.263158
# 2  1.272727
# 3  2.666667
# 4  3.666667

# %% [markdown]
# #### Skill Challenge

# %% [markdown]
# ###### **1.**

# %% [markdown]
# From the _players_ dataframe select 4 columns and 4 rows, of no particular order. Assign the resulting 4x4 dataframe to _df_random_.

# %% [markdown]
# ###### **2**.

# %% [markdown]
# Extend _df_random_ **1**) vertically by adding a new row, and **2**) horizontally by adding a new column. Do this as two separate operations.

# %% [markdown]
# ###### **3.**

# %% [markdown]
# Compare the relative performance of the operations above. Is adding a row or column faster? Is there a significant difference?

# %% [markdown]
# #### Solution

# %%
# 1

# %%
players.head()
# Out:
#                 name     club age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal  28       CM             1          65.0
# 1         Mesut Ozil  Arsenal  12       RW             1          50.0
# 2          Petr Cech  Arsenal  35       CB             4           7.0
# 3       Theo Walcott  Arsenal  28       GK             1          20.0
# 4  Laurent Koscielny  Arsenal  31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity  \
# 0            0        4        1         1            0  super-popular
# 1            0        4        1         1            0  super-popular
# 2            0        6        1         1            0        popular
# 3            0        4        1         1            0  super-popular
# 4            0        4        1         1            0        popular
#
#     MVtoFPL
# 0  5.416667
# 1  5.263158
# 2  1.272727
# 3  2.666667
# 4  3.666667

# %%
players.loc[0:3, 'name':'position']
# Out:
#              name     club age position
# 0  Alexis Sanchez  Arsenal  28       CM
# 1      Mesut Ozil  Arsenal  12       RW
# 2       Petr Cech  Arsenal  35       CB
# 3    Theo Walcott  Arsenal  28       GK

# %%
df_random = players.sample(4).sample(4, axis=1)

# %%
df_random
# Out:
#      market_value            club position  fpl_value
# 214           0.5  Leicester+City       GK        4.5
# 384          24.0       Tottenham       GK        5.5
# 423           8.0         Watford       CM        5.0
# 404           3.5         Watford       CB        4.5

# %%
# 2

# %%
df_random
# Out:
#      market_value            club position  fpl_value
# 214           0.5  Leicester+City       GK        4.5
# 384          24.0       Tottenham       GK        5.5
# 423           8.0         Watford       CM        5.0
# 404           3.5         Watford       CB        4.5

# %%
# adding a row

# %%
df_random.append(pd.Series({'nationality': 'Norway', 'age': 24, 'position': 'CM', 'club_id': 20}, name=307))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/627356141.py in ?()
# ----> 1 df_random.append(pd.Series({'nationality': 'Norway', 'age': 24, 'position': 'CM', 'club_id': 20}, name=307))
#
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# add a column

# %%
df_random.assign(years_in_league=[3, 6, 1, 10])
# Out:
#      market_value            club position  fpl_value  years_in_league
# 214           0.5  Leicester+City       GK        4.5                3
# 384          24.0       Tottenham       GK        5.5                6
# 423           8.0         Watford       CM        5.0                1
# 404           3.5         Watford       CB        4.5               10

# %%
# 3

# %%
# %%timeit
df_random.append(pd.Series({'nationality': 'Norway', 'age': 24, 'position': 'CM', 'club_id': 20}, name=307))
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/73/h1dfkft53c555yxwtttwgnfw0000gn/T/ipykernel_4070/2902587424.py", line 1, in <module>
#     get_ipython().run_cell_magic('timeit', '', "df_random.append(pd.Series({'nationality': 'Norway', 'age': 24, 'position': 'CM', 'club_id': 20}, name=307))\n")
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2478, in run_cell_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/magics/execution.py", line 1170, in timeit
#     time_number = timer.timeit(number)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/magics/execution.py", line 158, in timeit
#     timing = self.inner(it, self.timer)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<magic-timeit>", line 1, in inner
#   File "/opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'DataFrame' object has no attribute 'append'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1062, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1154, in get_records
#     FrameInfo(
#   File "/opt/homebrew/lib/python3.11/site-packages/IPython/core/ultratb.py", line 780, in __init__
#     ix = inspect.getsourcelines(frame)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py", line 1244, in getsourcelines
#     lines, lnum = findsource(object)
#                   ^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.4_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py", line 1081, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code

# %%
# %%timeit
df_random.assign(years_in_league=[3, 6, 1, 10])
# Out:
# 42.8 µs ± 919 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
4400/623
# Out:
# 7.062600321027287
